# %%
import pandas as pd

# Import selected questions
selected_questions_df = pd.read_csv('../data/new/sample_200_renamed.csv')

# Display info about the imported data
print("Selected questions dataset info:")
print(selected_questions_df.info())

print("\nSample of selected questions:")
print(selected_questions_df.head())
# Out:
# Selected questions dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   answerId             200 non-null    int64
#  1   isCorrect            200 non-null    bool
#  2   questionTitle        200 non-null    object
#  3   correctOptionLetter  200 non-null    object
#  4   studentAnswerLetter  200 non-null    object
#  5   studentAge           147 non-null    float64
#  6   userLevel            200 non-null    float64
#  7   userLevelPercentile  200 non-null    float64
#  8   topicName            200 non-null    object
#  9   subjectName          200 non-null    object
#  10  axisName             200 non-null    object
#  11  optionA              200 non-null    object
#  12  optionB              200 non-null    object
#  13  optionC              200 non-null    object
#  14  optionD              200 non-null    object
#  15  optionE              200 non-null    object
# dtypes: bool(1), float64(3), int64(1), object(11)
# memory usage: 23.8+ KB
# None
#
# Sample of selected questions:
#    answerId  isCorrect                                      questionTitle  \
# 0   1347929      False  En un estacionamiento hay `1.200` vehículos, d...
# 1   1452301      False  ¿Cuál es el valor de la expresión `1/5-2/3`?<b...
# 2   1593181      False     `487 - (-462 ÷ 11) + (1 · 31) + (125 - 96) = `
# 3   1462188      False  <div>La siguiente tabla, muestra la proyección...
# 4   1491793      False  <div>Juan estaba apostando en el casino con ci...
#
#         correctOptionLetter        studentAnswerLetter  studentAge  userLevel  \
# 0                    `300`                       `250`        13.0   0.166604
# 1                   `-7/15`                    `-1/15`        16.0  -0.152740
# 2                     `589`                      `590`         NaN  -3.000000
# 3                  IV=1,006                   IV=2,006         NaN  -1.014222
# 4  `9` dólares australianos  `19` dólares australianos        13.0  -2.263959
#
#    userLevelPercentile                                       topicName  \
# 0                 66.0                                    Porcentajes
# 1                 58.0              Suma y resta de números racionales
# 2                  0.0         Operatoria combinada de números enteros
# 3                 39.0  Cambio Porcentual Constante, Interés Compuesto
# 4                 14.0               División por números de una cifra
#
#           subjectName axisName                   optionA  \
# 0         Porcentajes  Números                     `350`
# 1  Números racionales  Números                      `-1`
# 2     Números Enteros  Números                     `590`
# 3  Números racionales  Números                  IV=1,006
# 4   Números Naturales  Números  `9` dólares australianos
#
#                     optionB                   optionC  \
# 0                     `400`                     `450`
# 1                    `-1/2`                    `-1/8`
# 2                     `591`                     `587`
# 3                  IV=0,006                  IV=2,006
# 4  `8` dólares australianos  `7` dólares australianos
#
#                      optionD                    optionE
# 0                      `250`                     `300`
# 1                    `-1/15`                    `-7/15`
# 2                      `588`                      `589`
# 3                    IV=1,06                     IV=1,6
# 4  `10` dólares australianos  `19` dólares australianos

# %%
import google.generativeai as genai

genai.configure(api_key="")

model = genai.GenerativeModel("gemini-2.0-flash-thinking-exp-01-21")

# %%
def get_prerequisites_for_question(row):
    """
    Get prerequisite topics for a given question by querying Gemini AI model.
    
    Args:
        row: Row from the questions dataframe
        
    Returns:
        String with the ids of the 5 most important/relevant topics as prerequisites for the question
    """
    response = model.generate_content(
        f"""Para la siguiente pregunta necesito que la revises detenidamente (la pregunta, el topico al que pertenece, el contexto del estudiante que la debe responder, etc) y luego revises la lista de topicos que te voy a compartir. Quiero que identifiques los 5 topicos de la lista más importantes/relevantes que debería saber un estudiante como prerequisito para responder la pregunta.

        Esta es la pregunta:
        %%%%
        <questionTitle>
        {row['questionTitle']}
        </questionTitle>

        <studentAge>
        {row['studentAge']}
        </studentAge>

        <topicName>
        {row['topicName']}
        </topicName>

        <subjectName>
        {row['subjectName']}
        </subjectName>

        <axisName>
        {row['axisName']}
        </axisName>
        %%%%

        Y esta es la lista de topicos de la cual quiero que identifiques los 5 más importantes/relevantes que debería saber un estudiante para responder correctamente la pregunta. En otras palabras, los topicos prerequisitos al topico de la pregunta. Esta es la lista:
        %%%%
        | topicId | topicName                                                                                   | subjectName                                       | axisName                    |
| ------- | ------------------------------------------------------------------------------------------- | ------------------------------------------------- | --------------------------- |
| 588     | Perímetro y Área del círculo                                                                | Círculo y circunferencia                          | Geometría                   |
| 661     | Multiplicación por decenas, centenas y unidades de 1.000                                    | Números Naturales                                 | Números                     |
| 666     | Ecuaciones e inecuaciones con adición y sustracción                                         | Ecuaciones de primer grado                        | Álgebra                     |
| 447     | Productos notables                                                                          | Productos Notables                                | Álgebra                     |
| 446     | Factorización                                                                               | Factorización                                     | Álgebra                     |
| 512     | Regla de LaPlace                                                                            | Cálculo de probabilidades                         | Probabilidad y estadísticas |
| 439     | Composición de funciones                                                                    | Función exponencial, logarítmica, raíz y potencia | Álgebra                     |
| 585     | eliminar esto                                                                               | Logaritmos                                        | Números                     |
| 502     | Propiedades y análisis gráfico                                                              | Distribución normal                               | Probabilidad y estadísticas |
| 428     | Propiedades de las raíces                                                                   | Raíces                                            | Números                     |
| 550     | Adición y sustracción de números enteros                                                    | Números Enteros                                   | Números                     |
| 449     | Desigualdades e intervalos                                                                  | Inecuaciones y sistemas de inecuaciones           | Álgebra                     |
| 662     | Comparación de Decimales                                                                    | Números racionales                                | Números                     |
| 667     | Diagrama de Tallo y Hojas                                                                   | Organización y representación de datos            | Probabilidad y estadísticas |
| 575     | Función Inyectiva                                                                           | Clasificación de Funciones y Función Inversa      | Álgebra                     |
| 577     | Función Biyectiva                                                                           | Clasificación de Funciones y Función Inversa      | Álgebra                     |
| 576     | Función Epiyectiva                                                                          | Clasificación de Funciones y Función Inversa      | Álgebra                     |
| 628     | Gráfico de barras dobles y circular                                                         | Organización y representación de datos            | Probabilidad y estadísticas |
| 594     | Muestreo Aleatorio                                                                          | Muestreo aleatorio                                | Probabilidad y estadísticas |
| 651     | Gráfica de Función de Probabilidad y de Distribución                                        | Variable aleatoria discreta y continua            | Probabilidad y estadísticas |
| 658     | Valor Posicional                                                                            | Números Naturales                                 | Números                     |
| 663     | Información en Tablas de Frecuencia                                                         | Organización y representación de datos            | Probabilidad y estadísticas |
| 613     | Lenguaje Algebraico                                                                         | Conceptos básicos algebraicos                     | Álgebra                     |
| 621     | Construcción de triángulos                                                                  | Figuras Geométricas                               | Geometría                   |
| 618     | Medición de Longitudes                                                                      | Unidad de Medida                                  | Geometría                   |
| 625     | Comprensión e interpretación del promedio                                                   | Medidas de tendencia central y posición           | Probabilidad y estadísticas |
| 626     | Resultados Posibles                                                                         | Cálculo de probabilidades                         | Probabilidad y estadísticas |
| 627     | Tendencia de Resultados en experimentos aleatorios                                          | Muestreo aleatorio                                | Probabilidad y estadísticas |
| 432     | Ecuaciones lineales con coeficientes enteros de la forma ax=b; x/a=b                        | Ecuaciones de primer grado                        | Álgebra                     |
| 484     | Teorema de Tales                                                                            | Homotecia y Teorema de Tales                      | Geometría                   |
| 498     | Comparación de conjuntos de datos                                                           | Medidas de tendencia central y posición           | Probabilidad y estadísticas |
| 655     | Vectores 3D                                                                                 | Puntos, planos y vectores                         | Geometría                   |
| 659     | Aproximación por redondeo                                                                   | Números Naturales                                 | Números                     |
| 664     | Gráfico de Barras y Líneas                                                                  | Organización y representación de datos            | Probabilidad y estadísticas |
| 642     | Magnitud de vectores                                                                        | Puntos, planos y vectores                         | Geometría                   |
| 508     | Tablas de frecuencia                                                                        | Organización y representación de datos            | Probabilidad y estadísticas |
| 497     | Rango de un conjunto de datos                                                               | Medidas de tendencia central y posición           | Probabilidad y estadísticas |
| 595     | Medidas de Tendencia Central                                                                | Medidas de tendencia central y posición           | Probabilidad y estadísticas |
| 495     | Medidas de tendencia central con datos agrupados                                            | Medidas de tendencia central y posición           | Probabilidad y estadísticas |
| 494     | Medidas de tendencia central con datos no agrupados                                         | Medidas de tendencia central y posición           | Probabilidad y estadísticas |
| 596     | Cálculo y Comparación de Probabilidades                                                     | Cálculo de probabilidades                         | Probabilidad y estadísticas |
| 496     | Medidas de posición                                                                         | Medidas de tendencia central y posición           | Probabilidad y estadísticas |
| 426     | Diagrama de Cajón                                                                           | Medidas de tendencia central y posición           | Probabilidad y estadísticas |
| 630     | Representaciones Gráficas                                                                   | Organización y representación de datos            | Probabilidad y estadísticas |
| 631     | Principio Combinatorio Multiplicativo                                                       | Cálculo de probabilidades                         | Probabilidad y estadísticas |
| 520     | Análisis de Dos Poblaciones                                                                 | Organización y representación de datos            | Probabilidad y estadísticas |
| 513     | Suma y producto de probabilidades                                                           | Cálculo de probabilidades                         | Probabilidad y estadísticas |
| 514     | Probabilidad condicional                                                                    | Cálculo de probabilidades                         | Probabilidad y estadísticas |
| 648     | Tabla de Galton                                                                             | Comportamiento Aleatorio                          | Probabilidad y estadísticas |
| 649     | Paseos Aleatorios                                                                           | Comportamiento Aleatorio                          | Probabilidad y estadísticas |
| 499     | Número y análisis de muestras                                                               | Muestreo aleatorio                                | Probabilidad y estadísticas |
| 509     | Histogramas                                                                                 | Organización y representación de datos            | Probabilidad y estadísticas |
| 515     | Ley de los grandes números                                                                  | Cálculo de probabilidades                         | Probabilidad y estadísticas |
| 510     | Polígonos de frecuencia                                                                     | Organización y representación de datos            | Probabilidad y estadísticas |
| 503     | Función de probabilidad y de distribución                                                   | Variable aleatoria discreta y continua            | Probabilidad y estadísticas |
| 511     | Técnicas de conteo                                                                          | Cálculo de probabilidades                         | Probabilidad y estadísticas |
| 652     | Probabilidad en la sociedad                                                                 | Cálculo de probabilidades                         | Probabilidad y estadísticas |
| 469     | Teorema de pitágoras                                                                        | Figuras Geométricas                               | Geometría                   |
| 519     | Perímetro y Área de sectores y segmentos circulares                                         | Círculo y circunferencia                          | Geometría                   |
| 656     | Modelos a Escala                                                                            | Semejanza y congruencia                           | Geometría                   |
| 475     | Operatoria de vectores                                                                      | Puntos, planos y vectores                         | Geometría                   |
| 528     | Proyecciones de Vectores con Razones Trigonométricas                                        | Trigonometría                                     | Geometría                   |
| 598     | Operaciones de Expresiones Algebraicas                                                      | Expresiones algebraicas                           | Álgebra                     |
| 427     | Problemas con expresiones algebraicas                                                       | Expresiones algebraicas                           | Álgebra                     |
| 653     | Probabilidad Total                                                                          | Cálculo de probabilidades                         | Probabilidad y estadísticas |
| 507     | Aproximación de la probabilidad binomial por la probabilidad de la normal.                  | Variable aleatoria discreta y continua            | Probabilidad y estadísticas |
| 500     | Distribución normal estándar                                                                | Distribución normal                               | Probabilidad y estadísticas |
| 504     | Valor esperado                                                                              | Variable aleatoria discreta y continua            | Probabilidad y estadísticas |
| 505     | Distribución binomial                                                                       | Variable aleatoria discreta y continua            | Probabilidad y estadísticas |
| 506     | Función de densidad                                                                         | Variable aleatoria discreta y continua            | Probabilidad y estadísticas |
| 501     | Intervalos de confianza                                                                     | Distribución normal                               | Probabilidad y estadísticas |
| 615     | Puntos y figuras en el plano cartesiano                                                     | Puntos, planos y vectores                         | Geometría                   |
| 616     | Caras, aristas y lados paralelos o perpendiculares                                          | Figuras Geométricas                               | Geometría                   |
| 482     | Congruencia de figuras                                                                      | Semejanza y congruencia                           | Geometría                   |
| 617     | Transformaciones isométricas, congruencia y figuras congruentes                             | Transformaciones isométricas                      | Geometría                   |
| 619     | Transformación de unidades de medida de longitud                                            | Unidad de Medida                                  | Geometría                   |
| 634     | Área de triángulos, paralelogramos, trapecios y figuras irregulares                         | Figuras Geométricas                               | Geometría                   |
| 622     | Ángulos en rectas que se intersectan                                                        | Ángulos                                           | Geometría                   |
| 623     | Cálculo de área de cubos y paralelepipedos                                                  | Cuerpos geométricos                               | Geometría                   |
| 624     | Cálculo de volumen de cubos y paralelepipedos                                               | Cuerpos geométricos                               | Geometría                   |
| 644     | Estimación y medición de ángulos                                                            | Ángulos                                           | Geometría                   |
| 467     | Ángulos complementarios y suplementarios                                                    | Ángulos                                           | Geometría                   |
| 587     | Suma de ángulos interiores y exteriores de polígonos                                        | Ángulos                                           | Geometría                   |
| 468     | Elementos secundarios del triángulos                                                        | Figuras Geométricas                               | Geometría                   |
| 589     | Área de paralelogramos, triángulos y trapecios                                              | Figuras Geométricas                               | Geometría                   |
| 590     | Vector Desplazamiento                                                                       | Puntos, planos y vectores                         | Geometría                   |
| 489     | Volumen de cuerpos geométricos                                                              | Cuerpos geométricos                               | Geometría                   |
| 488     | Área de cuerpos geometricos                                                                 | Cuerpos geométricos                               | Geometría                   |
| 478     | Traslación                                                                                  | Transformaciones isométricas                      | Geometría                   |
| 479     | Reflexión                                                                                   | Transformaciones isométricas                      | Geometría                   |
| 480     | Rotación                                                                                    | Transformaciones isométricas                      | Geometría                   |
| 481     | Composición de transformaciones                                                             | Transformaciones isométricas                      | Geometría                   |
| 522     | Volumen del Cono                                                                            | Cuerpos geométricos                               | Geometría                   |
| 487     | Homotecia de figuras planas                                                                 | Homotecia y Teorema de Tales                      | Geometría                   |
| 485     | División de segmentos                                                                       | Homotecia y Teorema de Tales                      | Geometría                   |
| 486     | Teorema de Euclides                                                                         | Semejanza y congruencia                           | Geometría                   |
| 483     | Semejanza de figuras                                                                        | Semejanza y congruencia                           | Geometría                   |
| 527     | Homotecia de Forma Vectorial                                                                | Homotecia y Teorema de Tales                      | Geometría                   |
| 529     | Gráficos XY y Nubes de Puntos                                                               | Puntos, planos y vectores                         | Geometría                   |
| 476     | Ecuación vectorial de la recta en 2D                                                        | Puntos, planos y vectores                         | Geometría                   |
| 477     | Ecuación vectorial de la recta en 3D                                                        | Puntos, planos y vectores                         | Geometría                   |
| 470     | Área del Cono                                                                               | Cuerpos geométricos                               | Geometría                   |
| 521     | Área y Volumen de la Esfera                                                                 | Cuerpos geométricos                               | Geometría                   |
| 525     | Razones Trigonométricas                                                                     | Trigonometría                                     | Geometría                   |
| 472     | Teoremas de cuerdas, secantes y tangentes.                                                  | Círculo y circunferencia                          | Geometría                   |
| 471     | Ángulos, arcos y sectores en la circunferencia                                              | Círculo y circunferencia                          | Geometría                   |
| 473     | Figuras geométricas en el plano                                                             | Puntos, planos y vectores                         | Geometría                   |
| 612     | Patrones de formación y secuencias                                                          | Conceptos básicos algebraicos                     | Álgebra                     |
| 607     | Razones                                                                                     | Proporcionalidad                                  | Álgebra                     |
| 614     | Representación y resolución de ecuaciones                                                   | Ecuaciones de primer grado                        | Álgebra                     |
| 639     | Valorización de expresiones algebraicas                                                     | Expresiones algebraicas                           | Álgebra                     |
| 448     | Lenguaje Algebraico                                                                         | Expresiones algebraicas                           | Álgebra                     |
| 445     | Reducción de expresiones algebraicas                                                        | Expresiones algebraicas                           | Álgebra                     |
| 629     | Proporcionalidad directa e inversa                                                          | Proporcionalidad                                  | Álgebra                     |
| 536     | Razones y tablas                                                                            | Proporcionalidad                                  | Álgebra                     |
| 450     | Inecuaciones lineales con coeficientes enteros de la forma ax=b; x/a=b                      | Inecuaciones y sistemas de inecuaciones           | Álgebra                     |
| 435     | Problemas con Ecuaciones lineales con coeficientes enteros de la forma ax=b; x/a=b          | Ecuaciones de primer grado                        | Álgebra                     |
| 458     | Dominio, recorrido y tipos de funciones                                                     | Clasificación de Funciones y Función Inversa      | Álgebra                     |
| 460     | Función lineal                                                                              | Función lineal y afín                             | Álgebra                     |
| 433     | Ecuaciones con coeficientes racionales                                                      | Ecuaciones de primer grado                        | Álgebra                     |
| 592     | Ecuaciones lineales con coeficientes enteros de la forma ax = b; x a(x+b)= c; ax + b=cx + d | Ecuaciones de primer grado                        | Álgebra                     |
| 593     | Inecuaciones lineales con coeficientes racionales                                           | Inecuaciones y sistemas de inecuaciones           | Álgebra                     |
| 459     | Función afín                                                                                | Función lineal y afín                             | Álgebra                     |
| 462     | Problemas de funciones afin y lineal                                                        | Función lineal y afín                             | Álgebra                     |
| 574     | Factorización: Otros                                                                        | Factorización                                     | Álgebra                     |
| 573     | Factorización: Trinomio de la forma x^2+px+q                                                | Factorización                                     | Álgebra                     |
| 571     | Factorización: Trinomio cuadrado perfecto                                                   | Factorización                                     | Álgebra                     |
| 572     | Factorización: Diferencia de cuadrados                                                      | Factorización                                     | Álgebra                     |
| 570     | Factorización: Factor Común (normal y compuesto)                                            | Factorización                                     | Álgebra                     |
| 569     | Productos Notables: Otros                                                                   | Productos Notables                                | Álgebra                     |
| 568     | Productos Notables: Binomio con término común                                               | Productos Notables                                | Álgebra                     |
| 567     | Productos Notables: Suma por Diferencia                                                     | Productos Notables                                | Álgebra                     |
| 566     | Productos Notables: Cuadrado de Binomio                                                     | Productos Notables                                | Álgebra                     |
| 453     | Existencia y pertinencia de soluciones                                                      | Sistemas de ecuaciones                            | Álgebra                     |
| 454     | Análisis gráfico                                                                            | Sistemas de ecuaciones                            | Álgebra                     |
| 641     | Ecuaciones lineales con 2 incógnitas                                                        | Ecuaciones de primer grado                        | Álgebra                     |
| 452     | Resolución de sistemas de ecuaciones                                                        | Sistemas de ecuaciones                            | Álgebra                     |
| 657     | Resolución de Sistema de Ecuaciones con única solución, infinitas soluciones o sin solución | Sistemas de ecuaciones                            | Álgebra                     |
| 548     | Problemas con sistema de ecuaciones                                                         | Sistemas de ecuaciones                            | Álgebra                     |
| 526     | Relaciones Lineales de Dos Variables                                                        | Función lineal y afín                             | Álgebra                     |
| 434     | Ecuaciones con coeficientes literales                                                       | Ecuaciones de primer grado                        | Álgebra                     |
| 442     | Suma y resta                                                                                | Fracciones algebraicas                            | Álgebra                     |
| 443     | Multiplicación y división                                                                   | Fracciones algebraicas                            | Álgebra                     |
| 444     | Simplificación                                                                              | Fracciones algebraicas                            | Álgebra                     |
| 451     | Sistemas de inecuaciones de primer grado                                                    | Inecuaciones y sistemas de inecuaciones           | Álgebra                     |
| 461     | Composición de funciones                                                                    | Función lineal y afín                             | Álgebra                     |
| 540     | Álgebra básica                                                                              | Conceptos básicos algebraicos                     | Álgebra                     |
| 546     | Problemas con Ecuaciones con coeficientes racionales                                        | Ecuaciones de primer grado                        | Álgebra                     |
| 465     | Análisis gráfico y discriminante                                                            | Función cuadrática                                | Álgebra                     |
| 463     | Intersección de la gráfica con los ejes coordenados                                         | Función cuadrática                                | Álgebra                     |
| 466     | Modelamiento de situaciones cotidianas                                                      | Función cuadrática                                | Álgebra                     |
| 650     | Variación de parámetros de la función cuadrática                                            | Función cuadrática                                | Álgebra                     |
| 464     | Vértice y eje de simetría                                                                   | Función cuadrática                                | Álgebra                     |
| 456     | Análisis de soluciones                                                                      | Ecuaciones de segundo grado                       | Álgebra                     |
| 457     | Propiedades de las soluciones                                                               | Ecuaciones de segundo grado                       | Álgebra                     |
| 455     | Resolución de ecuaciones de segundo grado                                                   | Ecuaciones de segundo grado                       | Álgebra                     |
| 438     | Función raíz                                                                                | Función exponencial, logarítmica, raíz y potencia | Álgebra                     |
| 440     | Función Inversa                                                                             | Clasificación de Funciones y Función Inversa      | Álgebra                     |
| 556     | Varianza y Desviación Estándar                                                              | Medidas de dispersión                             | Álgebra                     |
| 436     | Función exponencial                                                                         | Función exponencial, logarítmica, raíz y potencia | Álgebra                     |
| 437     | Función logarítmica                                                                         | Función exponencial, logarítmica, raíz y potencia | Álgebra                     |
| 441     | Traslación de gráfica de función exponencial                                                | Función exponencial, logarítmica, raíz y potencia | Álgebra                     |
| 647     | Traslación de gráfica de función logarítmica                                                | Función exponencial, logarítmica, raíz y potencia | Álgebra                     |
| 555     | Función Potencia                                                                            | Función exponencial, logarítmica, raíz y potencia | Álgebra                     |
| 646     | Traslación de gráfica de función potencia                                                   | Función exponencial, logarítmica, raíz y potencia | Álgebra                     |
| 474     | Distancia entre dos puntos y punto medio                                                    | Ecuación de la recta                              | Álgebra                     |
| 490     | Pendiente de una recta                                                                      | Ecuación de la recta                              | Álgebra                     |
| 491     | Ecuación punto-punto y punto-pendiente                                                      | Ecuación de la recta                              | Álgebra                     |
| 492     | Ecuación principal y general de la recta                                                    | Ecuación de la recta                              | Álgebra                     |
| 493     | Rectas paralelas y perpendiculares                                                          | Ecuación de la recta                              | Álgebra                     |
| 600     | Multiplicación entre números de dos cifras                                                  | Números Naturales                                 | Números                     |
| 601     | División por números de una cifra                                                           | Números Naturales                                 | Números                     |
| 603     | Problemas con cuatro operaciones                                                            | Números Naturales                                 | Números                     |
| 604     | Fracciones propias, equivalentes y comparación de fracciones                                | Números racionales                                | Números                     |
| 542     | Amplificación y simplificación de fracciones                                                | Números racionales                                | Números                     |
| 605     | Números mixtos y fracciones impropias                                                       | Números racionales                                | Números                     |
| 544     | Adición y Sustracción de números decimales                                                  | Números racionales                                | Números                     |
| 533     | División de números naturales                                                               | Números Naturales                                 | Números                     |
| 534     | Operatoria combinada de números naturales                                                   | Números Naturales                                 | Números                     |
| 532     | Multiplicación de números naturales                                                         | Números Naturales                                 | Números                     |
| 635     | Fracciones y Números Mixtos                                                                 | Números racionales                                | Números                     |
| 543     | Ejercicios de suma y resta de fracciones                                                    | Números racionales                                | Números                     |
| 610     | Multiplicación y división de números decimales                                              | Números racionales                                | Números                     |
| 611     | Problemas de adición y sustracción de fracciones, números mixtos y decimales                | Números racionales                                | Números                     |
| 554     | Problemas de adición y sustracción de números enteros                                       | Números Enteros                                   | Números                     |
| 549     | Ubicación y orden de números enteros en la recta numérica                                   | Números Enteros                                   | Números                     |
| 636     | Multiplicación y división entre números decimales                                           | Números racionales                                | Números                     |
| 547     | División de fracciones                                                                      | Números racionales                                | Números                     |
| 545     | Multiplicación de fracciones                                                                | Números racionales                                | Números                     |
| 413     | Transformación de decimal a fracción                                                        | Números racionales                                | Números                     |
| 421     | Valor Absoluto                                                                              | Números Enteros                                   | Números                     |
| 412     | Transformación de fracción a decimal                                                        | Números racionales                                | Números                     |
| 416     | Fracciones como porcentajes                                                                 | Números racionales                                | Números                     |
| 551     | Multiplicación de números enteros                                                           | Números Enteros                                   | Números                     |
| 552     | División de números enteros                                                                 | Números Enteros                                   | Números                     |
| 409     | Suma y resta de números racionales                                                          | Números racionales                                | Números                     |
| 410     | Multiplicación y división de números racionales                                             | Números racionales                                | Números                     |
| 541     | Fracciones Negativas                                                                        | Números racionales                                | Números                     |
| 411     | Representación de números racionales en la recta numérica                                   | Números racionales                                | Números                     |
| 415     | Orden de números racionales                                                                 | Números racionales                                | Números                     |
| 579     | Propiedad: Potencia de una potencia                                                         | Potencias                                         | Números                     |
| 583     | Suma y Resta de Potencias                                                                   | Potencias                                         | Números                     |
| 580     | Propiedad: Multiplicación y división de una potencia con distinta base e igual exponente    | Potencias                                         | Números                     |
| 578     | Propiedad: Multiplicación y División de potencias con igual base y distinto exponente       | Potencias                                         | Números                     |
| 597     | Variación Porcentual                                                                        | Números Enteros                                   | Números                     |
| 643     | Operaciones combinadas de números racionales                                                | Números racionales                                | Números                     |
| 524     | Potencias de Base Racional y Exponente Entero                                               | Potencias                                         | Números                     |
| 581     | Propiedad: Potencia de exponente negativo                                                   | Potencias                                         | Números                     |
| 584     | Multiplicación y División de Potencias                                                      | Potencias                                         | Números                     |
| 530     | Suma de números naturales                                                                   | Números Naturales                                 | Números                     |
| 531     | Resta de números naturales                                                                  | Números Naturales                                 | Números                     |
| 535     | Problemas de números naturales                                                              | Números Naturales                                 | Números                     |
| 538     | Potencias de base y exponente natural                                                       | Potencias                                         | Números                     |
| 602     | Operaciones combinadas de números naturales                                                 | Números Naturales                                 | Números                     |
| 417     | Identificar números racionales e irracionales                                               | Números reales                                    | Números                     |
| 419     | Aproximación de números reales                                                              | Números reales                                    | Números                     |
| 418     | Ubicación de números reales en la recta numérica                                            | Números reales                                    | Números                     |
| 420     | Orden de números reales                                                                     | Números reales                                    | Números                     |
| 414     | Aproximación de racionales                                                                  | Números racionales                                | Números                     |
| 645     | Operaciones con números reales                                                              | Números reales                                    | Números                     |
| 430     | Relación entre Potencias, Raíces y Logaritmos                                               | Logaritmos                                        | Números                     |
| 429     | Descomposición de Raíces                                                                    | Raíces                                            | Números                     |
| 431     | Ejercitación variada de logaritmos                                                          | Logaritmos                                        | Números                     |
| 563     | Propiedad: Logaritmo de la multiplicación                                                   | Logaritmos                                        | Números                     |
| 565     | Propiedad: Cambio de Base                                                                   | Logaritmos                                        | Números                     |
| 564     | Propiedad: Logaritmo de la división                                                         | Logaritmos                                        | Números                     |
| 539     | Raíces exactas                                                                              | Raíces                                            | Números                     |
| 559     | Propiedad: Multiplicación y División de Raíces con igual índice                             | Raíces                                            | Números                     |
| 561     | Propiedad: Raíz de una raíz                                                                 | Raíces                                            | Números                     |
| 558     | Multiplicación y División de Raíces                                                         | Raíces                                            | Números                     |
| 562     | Propiedad: Logaritmo de la unidad, de la base y de la potencia                              | Logaritmos                                        | Números                     |
| 582     | Propiedad: Potencia de exponente racional                                                   | Potencias                                         | Números                     |
| 560     | Propiedad: Multiplicación y División de Raíces con igual cantidad subradical                | Raíces                                            | Números                     |
| 586     | Ejercitación variada de raíces                                                              | Raíces                                            | Números                     |
| 422     | Introducción y propiedades                                                                  | Números complejos                                 | Números                     |
| 423     | Suma y resta de números complejos                                                           | Números complejos                                 | Números                     |
| 424     | Multiplicación de números complejos                                                         | Números complejos                                 | Números                     |
| 425     | División de números complejos                                                               | Números complejos                                 | Números                     |
| 537     | Porcentajes                                                                                 | Porcentajes                                       | Números                     |
| 654     | Toma de decisiones aplicando porcentajes                                                    | Porcentajes                                       | Números                     |
| 591     | Raíz Cuadrada                                                                               | Raíces                                            | Números                     |
| 557     | Suma y Resta de Raíces                                                                      | Raíces                                            | Números                     |
| 553     | Operatoria combinada de números enteros                                                     | Números Enteros                                   | Números                     |
| 523     | Cambio Porcentual Constante, Interés Compuesto                                              | Números racionales                                | Números                     |
| 660     | Comparación de números naturales                                                            | Números Naturales                                 | Números                     |
| 665     | Incógnitas con adición y sustracción                                                        | Expresiones algebraicas                           | Álgebra                     |
        %%%%

        Al final de tu respuesta debes escribir los ids en este formato: <ids>412,114,723,12,5532</ids> par que yo pueda extraer tu respuesta y procesarla.
        """
    )

    # Extract IDs between tags
    start_tag = '<ids>'
    end_tag = '</ids>'
    start_idx = response.text.find(start_tag) + len(start_tag)
    end_idx = response.text.find(end_tag)
    return response.text[start_idx:end_idx]

# %%
# Create new columns for prerequisite topic IDs
selected_questions_df[['pre1Id', 'pre2Id', 'pre3Id', 'pre4Id', 'pre5Id']] = None

print(f"Processing {len(selected_questions_df)} questions to find prerequisites...")

# Iterate through rows and get prerequisites 
for idx, row in selected_questions_df.iterrows():
    try:
        print(f"\nProcessing question {idx} ({row['topicName']})...")
        
        # Get prerequisite IDs string
        prereq_ids = get_prerequisites_for_question(row)
        print(f"Retrieved prerequisite IDs: {prereq_ids}")
        
        # Split into list and pad with None if less than 5 IDs
        id_list = prereq_ids.strip().split(',')
        id_list.extend([None] * (5 - len(id_list)))
        print(f"Padded ID list: {id_list[:5]}")
        
        # Assign to new columns
        selected_questions_df.loc[idx, ['pre1Id', 'pre2Id', 'pre3Id', 'pre4Id', 'pre5Id']] = id_list[:5]
        print(f"Row {idx} prerequisites:", selected_questions_df.loc[idx, ['pre1Id', 'pre2Id', 'pre3Id', 'pre4Id', 'pre5Id']])
        
    except Exception as e:
        print(f"Error processing row {idx}: {e}")
        selected_questions_df.loc[idx, ['pre1Id', 'pre2Id', 'pre3Id', 'pre4Id', 'pre5Id']] = [None] * 5

print("\nFinished processing all questions")
# Out:
# Processing 200 questions to find prerequisites...
#
# Processing question 0 (Porcentajes )...
# Retrieved prerequisite IDs: 661,550,532,603,530
# Padded ID list: ['661', '550', '532', '603', '530']
# Row 0 prerequisites: pre1Id    661
# pre2Id    550
# pre3Id    532
# pre4Id    603
# pre5Id    530
# Name: 0, dtype: object
#
# Processing question 1 (Suma y resta de números racionales)...
# Retrieved prerequisite IDs: 604,542,550,532,660
# Padded ID list: ['604', '542', '550', '532', '660']
# Row 1 prerequisites: pre1Id    604
# pre2Id    542
# pre3Id    550
# pre4Id    532
# pre5Id    660
# Name: 1, dtype: object
#
# Processing question 2 (Operatoria combinada de números enteros)...
# Retrieved prerequisite IDs: 550,551,552,534,549
# Padded ID list: ['550', '551', '552', '534', '549']
# Row 2 prerequisites: pre1Id    550
# pre2Id    551
# pre3Id    552
# pre4Id    534
# pre5Id    549
# Name: 2, dtype: object
#
# Processing question 3 (Cambio Porcentual Constante, Interés Compuesto)...
# Retrieved prerequisite IDs: 537,544,610,412,659
# Padded ID list: ['537', '544', '610', '412', '659']
# Row 3 prerequisites: pre1Id    537
# pre2Id    544
# pre3Id    610
# pre4Id    412
# pre5Id    659
# Name: 3, dtype: object
#
# Processing question 4 (División por números de una cifra)...
# Retrieved prerequisite IDs: 530,531,532,533,658
# Padded ID list: ['530', '531', '532', '533', '658']
# Row 4 prerequisites: pre1Id    530
# pre2Id    531
# pre3Id    532
# pre4Id    533
# pre5Id    658
# Name: 4, dtype: object
#
# Processing question 5 (Multiplicación y división de números racionales)...
# Retrieved prerequisite IDs: 604,542,409,410,415
# Padded ID list: ['604', '542', '409', '410', '415']
# Row 5 prerequisites: pre1Id    604
# pre2Id    542
# pre3Id    409
# pre4Id    410
# pre5Id    415
# Name: 5, dtype: object
#
# Processing question 6 (Orden de números racionales)...
# Retrieved prerequisite IDs: 604,662,412,542,409
# Padded ID list: ['604', '662', '412', '542', '409']
# Row 6 prerequisites: pre1Id    604
# pre2Id    662
# pre3Id    412
# pre4Id    542
# pre5Id    409
# Name: 6, dtype: object
#
# Processing question 7 (Variación Porcentual)...
# Retrieved prerequisite IDs: 537,550,552,551,416
# Padded ID list: ['537', '550', '552', '551', '416']
# Row 7 prerequisites: pre1Id    537
# pre2Id    550
# pre3Id    552
# pre4Id    551
# pre5Id    416
# Name: 7, dtype: object
#
# Processing question 8 (Fracciones como porcentajes)...
# Retrieved prerequisite IDs: 537,532,531,412,413
# Padded ID list: ['537', '532', '531', '412', '413']
# Row 8 prerequisites: pre1Id    537
# pre2Id    532
# pre3Id    531
# pre4Id    412
# pre5Id    413
# Name: 8, dtype: object
#
# Processing question 9 (Ejercitación variada de logaritmos)...
# Retrieved prerequisite IDs: 430,562,581,658,538
# Padded ID list: ['430', '562', '581', '658', '538']
# Row 9 prerequisites: pre1Id    430
# pre2Id    562
# pre3Id    581
# pre4Id    658
# pre5Id    538
# Name: 9, dtype: object
#
# Processing question 10 (Propiedad: Multiplicación y división de una potencia con distinta base e igual exponente)...
# Retrieved prerequisite IDs: 538,578,579,534,540
# Padded ID list: ['538', '578', '579', '534', '540']
# Row 10 prerequisites: pre1Id    538
# pre2Id    578
# pre3Id    579
# pre4Id    534
# pre5Id    540
# Name: 10, dtype: object
#
# Processing question 11 (Operatoria combinada de números enteros)...
# Retrieved prerequisite IDs: 550,551,603,530,532
# Padded ID list: ['550', '551', '603', '530', '532']
# Row 11 prerequisites: pre1Id    550
# pre2Id    551
# pre3Id    603
# pre4Id    530
# pre5Id    532
# Name: 11, dtype: object
#
# Processing question 12 (Propiedad: Multiplicación y División de potencias con igual base y distinto exponente)...
# Retrieved prerequisite IDs: 538,532,533,534,550
# Padded ID list: ['538', '532', '533', '534', '550']
# Row 12 prerequisites: pre1Id    538
# pre2Id    532
# pre3Id    533
# pre4Id    534
# pre5Id    550
# Name: 12, dtype: object
#
# Processing question 13 (Suma y resta de números racionales)...
# Retrieved prerequisite IDs: 550,604,543,542,415
# Padded ID list: ['550', '604', '543', '542', '415']
# Row 13 prerequisites: pre1Id    550
# pre2Id    604
# pre3Id    543
# pre4Id    542
# pre5Id    415
# Name: 13, dtype: object
#
# Processing question 14 (Suma y resta de números racionales)...
# Retrieved prerequisite IDs: 534,550,604,542,409
# Padded ID list: ['534', '550', '604', '542', '409']
# Row 14 prerequisites: pre1Id    534
# pre2Id    550
# pre3Id    604
# pre4Id    542
# pre5Id    409
# Name: 14, dtype: object
#
# Processing question 15 (Variación Porcentual)...
# Retrieved prerequisite IDs: 537,610,544,607,416
# Padded ID list: ['537', '610', '544', '607', '416']
# Row 15 prerequisites: pre1Id    537
# pre2Id    610
# pre3Id    544
# pre4Id    607
# pre5Id    416
# Name: 15, dtype: object
#
# Processing question 16 (Valor Absoluto)...
# Retrieved prerequisite IDs: 549,550,411,613,531
# Padded ID list: ['549', '550', '411', '613', '531']
# Row 16 prerequisites: pre1Id    549
# pre2Id    550
# pre3Id    411
# pre4Id    613
# pre5Id    531
# Name: 16, dtype: object
#
# Processing question 17 (Transformación de decimal a fracción)...
# Retrieved prerequisite IDs: 658,604,542,412,662
# Padded ID list: ['658', '604', '542', '412', '662']
# Row 17 prerequisites: pre1Id    658
# pre2Id    604
# pre3Id    542
# pre4Id    412
# pre5Id    662
# Name: 17, dtype: object
#
# Processing question 18 (Suma y resta de números racionales)...
# Retrieved prerequisite IDs: 550,543,643,604,541
# Padded ID list: ['550', '543', '643', '604', '541']
# Row 18 prerequisites: pre1Id    550
# pre2Id    543
# pre3Id    643
# pre4Id    604
# pre5Id    541
# Name: 18, dtype: object
#
# Processing question 19 (Multiplicación de números naturales)...
# Retrieved prerequisite IDs: 661,658,532,530,602
# Padded ID list: ['661', '658', '532', '530', '602']
# Row 19 prerequisites: pre1Id    661
# pre2Id    658
# pre3Id    532
# pre4Id    530
# pre5Id    602
# Name: 19, dtype: object
#
# Processing question 20 (Ejercicios de suma y resta de fracciones)...
# Retrieved prerequisite IDs: 604,542,601,531,550
# Padded ID list: ['604', '542', '601', '531', '550']
# Row 20 prerequisites: pre1Id    604
# pre2Id    542
# pre3Id    601
# pre4Id    531
# pre5Id    550
# Name: 20, dtype: object
#
# Processing question 21 (Suma y resta de números racionales)...
# Retrieved prerequisite IDs: 613,614,543,604,413
# Padded ID list: ['613', '614', '543', '604', '413']
# Row 21 prerequisites: pre1Id    613
# pre2Id    614
# pre3Id    543
# pre4Id    604
# pre5Id    413
# Name: 21, dtype: object
#
# Processing question 22 (Orden de números racionales)...
# Retrieved prerequisite IDs: 604,660,412,411,549
# Padded ID list: ['604', '660', '412', '411', '549']
# Row 22 prerequisites: pre1Id    604
# pre2Id    660
# pre3Id    412
# pre4Id    411
# pre5Id    549
# Name: 22, dtype: object
#
# Processing question 23 (Suma y resta de números racionales)...
# Retrieved prerequisite IDs: 550,533,603,409,613
# Padded ID list: ['550', '533', '603', '409', '613']
# Row 23 prerequisites: pre1Id    550
# pre2Id    533
# pre3Id    603
# pre4Id    409
# pre5Id    613
# Name: 23, dtype: object
#
# Processing question 24 (Suma y resta de números racionales)...
# Retrieved prerequisite IDs: 603,530,531,533,544
# Padded ID list: ['603', '530', '531', '533', '544']
# Row 24 prerequisites: pre1Id    603
# pre2Id    530
# pre3Id    531
# pre4Id    533
# pre5Id    544
# Name: 24, dtype: object
#
# Processing question 25 (Porcentajes )...
# Retrieved prerequisite IDs: 661,550,603,416,412
# Padded ID list: ['661', '550', '603', '416', '412']
# Row 25 prerequisites: pre1Id    661
# pre2Id    550
# pre3Id    603
# pre4Id    416
# pre5Id    412
# Name: 25, dtype: object
#
# Processing question 26 (Adición y sustracción de números enteros)...
# Retrieved prerequisite IDs: 549,660,530,421,531
# Padded ID list: ['549', '660', '530', '421', '531']
# Row 26 prerequisites: pre1Id    549
# pre2Id    660
# pre3Id    530
# pre4Id    421
# pre5Id    531
# Name: 26, dtype: object
#
# Processing question 27 (Toma de decisiones aplicando porcentajes)...
# Retrieved prerequisite IDs: 537,661,658,416,600
# Padded ID list: ['537', '661', '658', '416', '600']
# Row 27 prerequisites: pre1Id    537
# pre2Id    661
# pre3Id    658
# pre4Id    416
# pre5Id    600
# Name: 27, dtype: object
#
# Processing question 28 (División por números de una cifra)...
# Retrieved prerequisite IDs: 658,531,532,530,660
# Padded ID list: ['658', '531', '532', '530', '660']
# Row 28 prerequisites: pre1Id    658
# pre2Id    531
# pre3Id    532
# pre4Id    530
# pre5Id    660
# Name: 28, dtype: object
#
# Processing question 29 (Operaciones combinadas de números racionales)...
# Retrieved prerequisite IDs: 662,544,658,409,412
# Padded ID list: ['662', '544', '658', '409', '412']
# Row 29 prerequisites: pre1Id    662
# pre2Id    544
# pre3Id    658
# pre4Id    409
# pre5Id    412
# Name: 29, dtype: object
#
# Processing question 30 (Multiplicación y División de Raíces)...
# Retrieved prerequisite IDs: 550,445,428,558,533
# Padded ID list: ['550', '445', '428', '558', '533']
# Row 30 prerequisites: pre1Id    550
# pre2Id    445
# pre3Id    428
# pre4Id    558
# pre5Id    533
# Name: 30, dtype: object
#
# Processing question 31 (Suma y resta de números racionales)...
# Retrieved prerequisite IDs: 635,604,542,550,543
# Padded ID list: ['635', '604', '542', '550', '543']
# Row 31 prerequisites: pre1Id    635
# pre2Id    604
# pre3Id    542
# pre4Id    550
# pre5Id    543
# Name: 31, dtype: object
#
# Processing question 32 (División de números naturales)...
# Retrieved prerequisite IDs: 658,532,531,530,601
# Padded ID list: ['658', '532', '531', '530', '601']
# Row 32 prerequisites: pre1Id    658
# pre2Id    532
# pre3Id    531
# pre4Id    530
# pre5Id    601
# Name: 32, dtype: object
#
# Processing question 33 (Adición y sustracción de números enteros)...
# Retrieved prerequisite IDs: 530,531,549,660,658
# Padded ID list: ['530', '531', '549', '660', '658']
# Row 33 prerequisites: pre1Id    530
# pre2Id    531
# pre3Id    549
# pre4Id    660
# pre5Id    658
# Name: 33, dtype: object
#
# Processing question 34 (Propiedad: Multiplicación y división de una potencia con distinta base e igual exponente)...
# Retrieved prerequisite IDs: 538,579,578,534,532
# Padded ID list: ['538', '579', '578', '534', '532']
# Row 34 prerequisites: pre1Id    538
# pre2Id    579
# pre3Id    578
# pre4Id    534
# pre5Id    532
# Name: 34, dtype: object
#
# Processing question 35 (Aproximación de racionales)...
# Retrieved prerequisite IDs: 658,415,659,544,662
# Padded ID list: ['658', '415', '659', '544', '662']
# Row 35 prerequisites: pre1Id    658
# pre2Id    415
# pre3Id    659
# pre4Id    544
# pre5Id    662
# Name: 35, dtype: object
#
# Processing question 36 (Suma y resta de números racionales)...
# Retrieved prerequisite IDs: 603,533,550,613,604
# Padded ID list: ['603', '533', '550', '613', '604']
# Row 36 prerequisites: pre1Id    603
# pre2Id    533
# pre3Id    550
# pre4Id    613
# pre5Id    604
# Name: 36, dtype: object
#
# Processing question 37 (Multiplicación de fracciones)...
# Retrieved prerequisite IDs: 604,532,542,410,545
# Padded ID list: ['604', '532', '542', '410', '545']
# Row 37 prerequisites: pre1Id    604
# pre2Id    532
# pre3Id    542
# pre4Id    410
# pre5Id    545
# Name: 37, dtype: object
#
# Processing question 38 (Multiplicación de números enteros)...
# Retrieved prerequisite IDs: 532,550,549,658,554
# Padded ID list: ['532', '550', '549', '658', '554']
# Row 38 prerequisites: pre1Id    532
# pre2Id    550
# pre3Id    549
# pre4Id    658
# pre5Id    554
# Name: 38, dtype: object
#
# Processing question 39 (Operaciones combinadas de números racionales)...
# Error processing row 39: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
#
# Processing question 40 (Ubicación y orden de números enteros en la recta numérica)...
# Retrieved prerequisite IDs: 660,658,550,662,421
# Padded ID list: ['660', '658', '550', '662', '421']
# Row 40 prerequisites: pre1Id    660
# pre2Id    658
# pre3Id    550
# pre4Id    662
# pre5Id    421
# Name: 40, dtype: object
#
# Processing question 41 (Operatoria combinada de números enteros)...
# Retrieved prerequisite IDs: 550,551,552,534,603
# Padded ID list: ['550', '551', '552', '534', '603']
# Row 41 prerequisites: pre1Id    550
# pre2Id    551
# pre3Id    552
# pre4Id    534
# pre5Id    603
# Name: 41, dtype: object
#
# Processing question 42 (Descomposición de Raíces)...
# Error processing row 42: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
#
# Processing question 43 (Operatoria combinada de números enteros)...
# Retrieved prerequisite IDs: 658,530,532,550,603
# Padded ID list: ['658', '530', '532', '550', '603']
# Row 43 prerequisites: pre1Id    658
# pre2Id    530
# pre3Id    532
# pre4Id    550
# pre5Id    603
# Name: 43, dtype: object
#
# Processing question 44 (Multiplicación de números enteros)...
# Retrieved prerequisite IDs: 530,532,535,658,603
# Padded ID list: ['530', '532', '535', '658', '603']
# Row 44 prerequisites: pre1Id    530
# pre2Id    532
# pre3Id    535
# pre4Id    658
# pre5Id    603
# Name: 44, dtype: object
#
# Processing question 45 (Aproximación de racionales)...
# Retrieved prerequisite IDs: 409,543,412,659,542
# Padded ID list: ['409', '543', '412', '659', '542']
# Row 45 prerequisites: pre1Id    409
# pre2Id    543
# pre3Id    412
# pre4Id    659
# pre5Id    542
# Name: 45, dtype: object
#
# Processing question 46 (Ejercicios de suma y resta de fracciones)...
# Retrieved prerequisite IDs: 604,530,531,542,411
# Padded ID list: ['604', '530', '531', '542', '411']
# Row 46 prerequisites: pre1Id    604
# pre2Id    530
# pre3Id    531
# pre4Id    542
# pre5Id    411
# Name: 46, dtype: object
#
# Processing question 47 (Transformación de decimal a fracción)...
# Retrieved prerequisite IDs: 658,662,604,635,412
# Padded ID list: ['658', '662', '604', '635', '412']
# Row 47 prerequisites: pre1Id    658
# pre2Id    662
# pre3Id    604
# pre4Id    635
# pre5Id    412
# Name: 47, dtype: object
#
# Processing question 48 (Ejercicios de suma y resta de fracciones)...
# Retrieved prerequisite IDs: 530,604,542,635,605
# Padded ID list: ['530', '604', '542', '635', '605']
# Row 48 prerequisites: pre1Id    530
# pre2Id    604
# pre3Id    542
# pre4Id    635
# pre5Id    605
# Name: 48, dtype: object
#
# Processing question 49 (Cambio Porcentual Constante, Interés Compuesto)...
# Retrieved prerequisite IDs: 604,412,416,533,532
# Padded ID list: ['604', '412', '416', '533', '532']
# Row 49 prerequisites: pre1Id    604
# pre2Id    412
# pre3Id    416
# pre4Id    533
# pre5Id    532
# Name: 49, dtype: object
#
# Processing question 50 (Factorización: Otros)...
# Retrieved prerequisite IDs: 613,598,410,550,445
# Padded ID list: ['613', '598', '410', '550', '445']
# Row 50 prerequisites: pre1Id    613
# pre2Id    598
# pre3Id    410
# pre4Id    550
# pre5Id    445
# Name: 50, dtype: object
#
# Processing question 51 (Ecuaciones con coeficientes literales)...
# Retrieved prerequisite IDs: 613,598,614,445,666
# Padded ID list: ['613', '598', '614', '445', '666']
# Row 51 prerequisites: pre1Id    613
# pre2Id    598
# pre3Id    614
# pre4Id    445
# pre5Id    666
# Name: 51, dtype: object
#
# Processing question 52 (Razones)...
# Retrieved prerequisite IDs: 658,660,604,542,533
# Padded ID list: ['658', '660', '604', '542', '533']
# Row 52 prerequisites: pre1Id    658
# pre2Id    660
# pre3Id    604
# pre4Id    542
# pre5Id    533
# Name: 52, dtype: object
#
# Processing question 53 (Inecuaciones lineales con coeficientes enteros de la forma ax=b; x/a=b)...
# Retrieved prerequisite IDs: 613,666,432,449,658
# Padded ID list: ['613', '666', '432', '449', '658']
# Row 53 prerequisites: pre1Id    613
# pre2Id    666
# pre3Id    432
# pre4Id    449
# pre5Id    658
# Name: 53, dtype: object
#
# Processing question 54 (Problemas de funciones afin y lineal)...
# Retrieved prerequisite IDs: 615,492,589,614,613
# Padded ID list: ['615', '492', '589', '614', '613']
# Row 54 prerequisites: pre1Id    615
# pre2Id    492
# pre3Id    589
# pre4Id    614
# pre5Id    613
# Name: 54, dtype: object
#
# Processing question 55 (Productos Notables: Cuadrado de Binomio)...
# Retrieved prerequisite IDs: 613,598,445,540,550
# Padded ID list: ['613', '598', '445', '540', '550']
# Row 55 prerequisites: pre1Id    613
# pre2Id    598
# pre3Id    445
# pre4Id    540
# pre5Id    550
# Name: 55, dtype: object
#
# Processing question 56 (Ecuaciones con coeficientes racionales)...
# Retrieved prerequisite IDs: 613,409,666,614,540
# Padded ID list: ['613', '409', '666', '614', '540']
# Row 56 prerequisites: pre1Id    613
# pre2Id    409
# pre3Id    666
# pre4Id    614
# pre5Id    540
# Name: 56, dtype: object
#
# Processing question 57 (Problemas de funciones afin y lineal)...
# Retrieved prerequisite IDs: 613,540,550,532,427
# Padded ID list: ['613', '540', '550', '532', '427']
# Row 57 prerequisites: pre1Id    613
# pre2Id    540
# pre3Id    550
# pre4Id    532
# pre5Id    427
# Name: 57, dtype: object
#
# Processing question 58 (Productos Notables: Cuadrado de Binomio)...
# Retrieved prerequisite IDs: 598,445,448,550,551
# Padded ID list: ['598', '445', '448', '550', '551']
# Row 58 prerequisites: pre1Id    598
# pre2Id    445
# pre3Id    448
# pre4Id    550
# pre5Id    551
# Name: 58, dtype: object
#
# Processing question 59 (Proporcionalidad directa e inversa)...
# Retrieved prerequisite IDs: 607,629,536,613,603
# Padded ID list: ['607', '629', '536', '613', '603']
# Row 59 prerequisites: pre1Id    607
# pre2Id    629
# pre3Id    536
# pre4Id    613
# pre5Id    603
# Name: 59, dtype: object
#
# Processing question 60 (Factorización: Diferencia de cuadrados)...
# Retrieved prerequisite IDs: 613,598,666,447,567
# Padded ID list: ['613', '598', '666', '447', '567']
# Row 60 prerequisites: pre1Id    613
# pre2Id    598
# pre3Id    666
# pre4Id    447
# pre5Id    567
# Name: 60, dtype: object
#
# Processing question 61 (Ecuaciones lineales con coeficientes enteros de la forma ax=b; x/a=b)...
# Retrieved prerequisite IDs: 613,666,550,612,614
# Padded ID list: ['613', '666', '550', '612', '614']
# Row 61 prerequisites: pre1Id    613
# pre2Id    666
# pre3Id    550
# pre4Id    612
# pre5Id    614
# Name: 61, dtype: object
#
# Processing question 62 (Varianza y Desviación Estándar)...
# Retrieved prerequisite IDs: 625,496,497,659,662
# Padded ID list: ['625', '496', '497', '659', '662']
# Row 62 prerequisites: pre1Id    625
# pre2Id    496
# pre3Id    497
# pre4Id    659
# pre5Id    662
# Name: 62, dtype: object
#
# Processing question 63 (Productos Notables: Otros)...
# Retrieved prerequisite IDs: 598,445,540,613,551
# Padded ID list: ['598', '445', '540', '613', '551']
# Row 63 prerequisites: pre1Id    598
# pre2Id    445
# pre3Id    540
# pre4Id    613
# pre5Id    551
# Name: 63, dtype: object
#
# Processing question 64 (Productos Notables: Binomio con término común)...
# Retrieved prerequisite IDs: 598,613,532,550,445
# Padded ID list: ['598', '613', '532', '550', '445']
# Row 64 prerequisites: pre1Id    598
# pre2Id    613
# pre3Id    532
# pre4Id    550
# pre5Id    445
# Name: 64, dtype: object
#
# Processing question 65 (Ecuaciones lineales con coeficientes enteros de la forma ax=b; x/a=b)...
# Retrieved prerequisite IDs: 540,613,598,550,614
# Padded ID list: ['540', '613', '598', '550', '614']
# Row 65 prerequisites: pre1Id    540
# pre2Id    613
# pre3Id    598
# pre4Id    550
# pre5Id    614
# Name: 65, dtype: object
#
# Processing question 66 (Inecuaciones lineales con coeficientes enteros de la forma ax=b; x/a=b)...
# Retrieved prerequisite IDs: 613,603,666,661,614
# Padded ID list: ['613', '603', '666', '661', '614']
# Row 66 prerequisites: pre1Id    613
# pre2Id    603
# pre3Id    666
# pre4Id    661
# pre5Id    614
# Name: 66, dtype: object
#
# Processing question 67 (Valorización de expresiones algebraicas)...
# Retrieved prerequisite IDs: 613,598,614,639,540
# Padded ID list: ['613', '598', '614', '639', '540']
# Row 67 prerequisites: pre1Id    613
# pre2Id    598
# pre3Id    614
# pre4Id    639
# pre5Id    540
# Name: 67, dtype: object
#
# Processing question 68 (Reducción de expresiones algebraicas)...
# Retrieved prerequisite IDs: 613,540,550,598,665
# Padded ID list: ['613', '540', '550', '598', '665']
# Row 68 prerequisites: pre1Id    613
# pre2Id    540
# pre3Id    550
# pre4Id    598
# pre5Id    665
# Name: 68, dtype: object
#
# Processing question 69 (Productos Notables: Binomio con término común)...
# Retrieved prerequisite IDs: 613,598,445,550,551
# Padded ID list: ['613', '598', '445', '550', '551']
# Row 69 prerequisites: pre1Id    613
# pre2Id    598
# pre3Id    445
# pre4Id    550
# pre5Id    551
# Name: 69, dtype: object
#
# Processing question 70 (Problemas de funciones afin y lineal)...
# Retrieved prerequisite IDs: 613,448,639,427,603
# Padded ID list: ['613', '448', '639', '427', '603']
# Row 70 prerequisites: pre1Id    613
# pre2Id    448
# pre3Id    639
# pre4Id    427
# pre5Id    603
# Name: 70, dtype: object
#
# Processing question 71 (Resolución de Sistema de Ecuaciones con única  solución, infinitas soluciones o sin solución)...
# Retrieved prerequisite IDs: 639,598,641,433,613
# Padded ID list: ['639', '598', '641', '433', '613']
# Row 71 prerequisites: pre1Id    639
# pre2Id    598
# pre3Id    641
# pre4Id    433
# pre5Id    613
# Name: 71, dtype: object
#
# Processing question 72 (Inecuaciones lineales con coeficientes racionales)...
# Retrieved prerequisite IDs: 421,449,666,550,613
# Padded ID list: ['421', '449', '666', '550', '613']
# Row 72 prerequisites: pre1Id    421
# pre2Id    449
# pre3Id    666
# pre4Id    550
# pre5Id    613
# Name: 72, dtype: object
#
# Processing question 73 (Ecuaciones lineales con coeficientes enteros de la forma ax=b; x/a=b)...
# Retrieved prerequisite IDs: 666,432,550,600,598
# Padded ID list: ['666', '432', '550', '600', '598']
# Row 73 prerequisites: pre1Id    666
# pre2Id    432
# pre3Id    550
# pre4Id    600
# pre5Id    598
# Name: 73, dtype: object
#
# Processing question 74 (Ecuaciones lineales con coeficientes enteros de la forma ax=b; x/a=b)...
# Retrieved prerequisite IDs: 613,550,666,658,614
# Padded ID list: ['613', '550', '666', '658', '614']
# Row 74 prerequisites: pre1Id    613
# pre2Id    550
# pre3Id    666
# pre4Id    658
# pre5Id    614
# Name: 74, dtype: object
#
# Processing question 75 (Problemas de funciones afin y lineal)...
# Retrieved prerequisite IDs: 550,613,658,530,598
# Padded ID list: ['550', '613', '658', '530', '598']
# Row 75 prerequisites: pre1Id    550
# pre2Id    613
# pre3Id    658
# pre4Id    530
# pre5Id    598
# Name: 75, dtype: object
#
# Processing question 76 (Patrones de formación y secuencias)...
# Retrieved prerequisite IDs: 613,540,534,658,603
# Padded ID list: ['613', '540', '534', '658', '603']
# Row 76 prerequisites: pre1Id    613
# pre2Id    540
# pre3Id    534
# pre4Id    658
# pre5Id    603
# Name: 76, dtype: object
#
# Processing question 77 (Productos Notables: Binomio con término común)...
# Retrieved prerequisite IDs: 540,598,445,550,551
# Padded ID list: ['540', '598', '445', '550', '551']
# Row 77 prerequisites: pre1Id    540
# pre2Id    598
# pre3Id    445
# pre4Id    550
# pre5Id    551
# Name: 77, dtype: object
#
# Processing question 78 (Razones)...
# Retrieved prerequisite IDs: 607,542,604,532,533
# Padded ID list: ['607', '542', '604', '532', '533']
# Row 78 prerequisites: pre1Id    607
# pre2Id    542
# pre3Id    604
# pre4Id    532
# pre5Id    533
# Name: 78, dtype: object
#
# Processing question 79 (Función exponencial)...
# Retrieved prerequisite IDs: 639,613,538,550,615
# Padded ID list: ['639', '613', '538', '550', '615']
# Row 79 prerequisites: pre1Id    639
# pre2Id    613
# pre3Id    538
# pre4Id    550
# pre5Id    615
# Name: 79, dtype: object
#
# Processing question 80 (Resolución de Sistema de Ecuaciones con única  solución, infinitas soluciones o sin solución)...
# Retrieved prerequisite IDs: 613,641,666,432,598
# Padded ID list: ['613', '641', '666', '432', '598']
# Row 80 prerequisites: pre1Id    613
# pre2Id    641
# pre3Id    666
# pre4Id    432
# pre5Id    598
# Name: 80, dtype: object
#
# Processing question 81 (Productos Notables: Cuadrado de Binomio)...
# Retrieved prerequisite IDs: 540,598,445,613,447
# Padded ID list: ['540', '598', '445', '613', '447']
# Row 81 prerequisites: pre1Id    540
# pre2Id    598
# pre3Id    445
# pre4Id    613
# pre5Id    447
# Name: 81, dtype: object
#
# Processing question 82 (Proporcionalidad directa e inversa)...
# Retrieved prerequisite IDs: 603,532,533,607,658
# Padded ID list: ['603', '532', '533', '607', '658']
# Row 82 prerequisites: pre1Id    603
# pre2Id    532
# pre3Id    533
# pre4Id    607
# pre5Id    658
# Name: 82, dtype: object
#
# Processing question 83 (Productos Notables: Cuadrado de Binomio)...
# Retrieved prerequisite IDs: 613,598,427,445,538
# Padded ID list: ['613', '598', '427', '445', '538']
# Row 83 prerequisites: pre1Id    613
# pre2Id    598
# pre3Id    427
# pre4Id    445
# pre5Id    538
# Name: 83, dtype: object
#
# Processing question 84 (Ecuaciones lineales con coeficientes enteros de la forma ax=b; x/a=b)...
# Retrieved prerequisite IDs: 613,598,534,639,666
# Padded ID list: ['613', '598', '534', '639', '666']
# Row 84 prerequisites: pre1Id    613
# pre2Id    598
# pre3Id    534
# pre4Id    639
# pre5Id    666
# Name: 84, dtype: object
#
# Processing question 85 (Razones)...
# Retrieved prerequisite IDs: 604,542,410,536,658
# Padded ID list: ['604', '542', '410', '536', '658']
# Row 85 prerequisites: pre1Id    604
# pre2Id    542
# pre3Id    410
# pre4Id    536
# pre5Id    658
# Name: 85, dtype: object
#
# Processing question 86 (Ecuaciones con coeficientes racionales)...
# Retrieved prerequisite IDs: 613,614,409,410,666
# Padded ID list: ['613', '614', '409', '410', '666']
# Row 86 prerequisites: pre1Id    613
# pre2Id    614
# pre3Id    409
# pre4Id    410
# pre5Id    666
# Name: 86, dtype: object
#
# Processing question 87 (Representación y resolución de ecuaciones)...
# Retrieved prerequisite IDs: 666,432,550,601,613
# Padded ID list: ['666', '432', '550', '601', '613']
# Row 87 prerequisites: pre1Id    666
# pre2Id    432
# pre3Id    550
# pre4Id    601
# pre5Id    613
# Name: 87, dtype: object
#
# Processing question 88 (Ecuaciones lineales con coeficientes enteros de la forma ax=b; x/a=b)...
# Retrieved prerequisite IDs: 531,532,666,658,613
# Padded ID list: ['531', '532', '666', '658', '613']
# Row 88 prerequisites: pre1Id    531
# pre2Id    532
# pre3Id    666
# pre4Id    658
# pre5Id    613
# Name: 88, dtype: object
#
# Processing question 89 (Reducción de expresiones algebraicas)...
# Retrieved prerequisite IDs: 613,598,665,550,540
# Padded ID list: ['613', '598', '665', '550', '540']
# Row 89 prerequisites: pre1Id    613
# pre2Id    598
# pre3Id    665
# pre4Id    550
# pre5Id    540
# Name: 89, dtype: object
#
# Processing question 90 (Problemas con expresiones algebraicas)...
# Retrieved prerequisite IDs: 530,630,613,663,550
# Padded ID list: ['530', '630', '613', '663', '550']
# Row 90 prerequisites: pre1Id    530
# pre2Id    630
# pre3Id    613
# pre4Id    663
# pre5Id    550
# Name: 90, dtype: object
#
# Processing question 91 (Ecuaciones con coeficientes racionales)...
# Retrieved prerequisite IDs: 613,409,614,432,666
# Padded ID list: ['613', '409', '614', '432', '666']
# Row 91 prerequisites: pre1Id    613
# pre2Id    409
# pre3Id    614
# pre4Id    432
# pre5Id    666
# Name: 91, dtype: object
#
# Processing question 92 (Valorización de expresiones algebraicas)...
# Retrieved prerequisite IDs: 613,550,551,602,540
# Padded ID list: ['613', '550', '551', '602', '540']
# Row 92 prerequisites: pre1Id    613
# pre2Id    550
# pre3Id    551
# pre4Id    602
# pre5Id    540
# Name: 92, dtype: object
#
# Processing question 93 (Valorización de expresiones algebraicas)...
# Retrieved prerequisite IDs: 613,666,432,550,533
# Padded ID list: ['613', '666', '432', '550', '533']
# Row 93 prerequisites: pre1Id    613
# pre2Id    666
# pre3Id    432
# pre4Id    550
# pre5Id    533
# Name: 93, dtype: object
#
# Processing question 94 (Problemas con Ecuaciones con coeficientes racionales)...
# Retrieved prerequisite IDs: 613,614,604,543,545
# Padded ID list: ['613', '614', '604', '543', '545']
# Row 94 prerequisites: pre1Id    613
# pre2Id    614
# pre3Id    604
# pre4Id    543
# pre5Id    545
# Name: 94, dtype: object
#
# Processing question 95 (Proporcionalidad directa e inversa)...
# Retrieved prerequisite IDs: 603,533,532,658,607
# Padded ID list: ['603', '533', '532', '658', '607']
# Row 95 prerequisites: pre1Id    603
# pre2Id    533
# pre3Id    532
# pre4Id    658
# pre5Id    607
# Name: 95, dtype: object
#
# Processing question 96 (Ecuaciones lineales con coeficientes enteros de la forma ax = b; x  a(x+b)= c; ax + b=cx + d)...
# Retrieved prerequisite IDs: 613,666,614,432,550
# Padded ID list: ['613', '666', '614', '432', '550']
# Row 96 prerequisites: pre1Id    613
# pre2Id    666
# pre3Id    614
# pre4Id    432
# pre5Id    550
# Name: 96, dtype: object
#
# Processing question 97 (Valorización de expresiones algebraicas)...
# Retrieved prerequisite IDs: 618,588,613,598,603
# Padded ID list: ['618', '588', '613', '598', '603']
# Row 97 prerequisites: pre1Id    618
# pre2Id    588
# pre3Id    613
# pre4Id    598
# pre5Id    603
# Name: 97, dtype: object
#
# Processing question 98 (Varianza y Desviación Estándar)...
# Retrieved prerequisite IDs: 625,534,595,538,663
# Padded ID list: ['625', '534', '595', '538', '663']
# Row 98 prerequisites: pre1Id    625
# pre2Id    534
# pre3Id    595
# pre4Id    538
# pre5Id    663
# Name: 98, dtype: object
#
# Processing question 99 (Valorización de expresiones algebraicas)...
# Retrieved prerequisite IDs: 618,613,550,665,588
# Padded ID list: ['618', '613', '550', '665', '588']
# Row 99 prerequisites: pre1Id    618
# pre2Id    613
# pre3Id    550
# pre4Id    665
# pre5Id    588
# Name: 99, dtype: object
#
# Processing question 100 (Perímetro y Área de sectores y segmentos circulares)...
# Retrieved prerequisite IDs: 588,634,604,602,618
# Padded ID list: ['588', '634', '604', '602', '618']
# Row 100 prerequisites: pre1Id    588
# pre2Id    634
# pre3Id    604
# pre4Id    602
# pre5Id    618
# Name: 100, dtype: object
#
# Processing question 101 (Teorema de Tales)...
# Retrieved prerequisite IDs: 607,629,618,432,483
# Padded ID list: ['607', '629', '618', '432', '483']
# Row 101 prerequisites: pre1Id    607
# pre2Id    629
# pre3Id    618
# pre4Id    432
# pre5Id    483
# Name: 101, dtype: object
#
# Processing question 102 (Teorema de Tales)...
# Retrieved prerequisite IDs: 607,629,613,432,618
# Padded ID list: ['607', '629', '613', '432', '618']
# Row 102 prerequisites: pre1Id    607
# pre2Id    629
# pre3Id    613
# pre4Id    432
# pre5Id    618
# Name: 102, dtype: object
#
# Processing question 103 (Perímetro y Área del círculo)...
# Retrieved prerequisite IDs: 618,473,619,532,613
# Padded ID list: ['618', '473', '619', '532', '613']
# Row 103 prerequisites: pre1Id    618
# pre2Id    473
# pre3Id    619
# pre4Id    532
# pre5Id    613
# Name: 103, dtype: object
#
# Processing question 104 (Perímetro y Área de sectores y segmentos circulares)...
# Retrieved prerequisite IDs: 588,604,601,532,607
# Padded ID list: ['588', '604', '601', '532', '607']
# Row 104 prerequisites: pre1Id    588
# pre2Id    604
# pre3Id    601
# pre4Id    532
# pre5Id    607
# Name: 104, dtype: object
#
# Processing question 105 (Teorema de pitágoras)...
# Retrieved prerequisite IDs: 618,616,550,661,591
# Padded ID list: ['618', '616', '550', '661', '591']
# Row 105 prerequisites: pre1Id    618
# pre2Id    616
# pre3Id    550
# pre4Id    661
# pre5Id    591
# Name: 105, dtype: object
#
# Processing question 106 (Traslación)...
# Retrieved prerequisite IDs: 615,550,439,540,478
# Padded ID list: ['615', '550', '439', '540', '478']
# Row 106 prerequisites: pre1Id    615
# pre2Id    550
# pre3Id    439
# pre4Id    540
# pre5Id    478
# Name: 106, dtype: object
#
# Processing question 107 (Teorema de pitágoras)...
# Retrieved prerequisite IDs: 614,615,474,492,613
# Padded ID list: ['614', '615', '474', '492', '613']
# Row 107 prerequisites: pre1Id    614
# pre2Id    615
# pre3Id    474
# pre4Id    492
# pre5Id    613
# Name: 107, dtype: object
#
# Processing question 108 (Razones Trigonométricas)...
# Retrieved prerequisite IDs: 621,622,618,613,432
# Padded ID list: ['621', '622', '618', '613', '432']
# Row 108 prerequisites: pre1Id    621
# pre2Id    622
# pre3Id    618
# pre4Id    613
# pre5Id    432
# Name: 108, dtype: object
#
# Processing question 109 (Ángulos, arcos y sectores en la circunferencia)...
# Retrieved prerequisite IDs: 618,644,622,467,629
# Padded ID list: ['618', '644', '622', '467', '629']
# Row 109 prerequisites: pre1Id    618
# pre2Id    644
# pre3Id    622
# pre4Id    467
# pre5Id    629
# Name: 109, dtype: object
#
# Processing question 110 (Teoremas de cuerdas, secantes y tangentes.)...
# Retrieved prerequisite IDs: 469,618,622,473,591
# Padded ID list: ['469', '618', '622', '473', '591']
# Row 110 prerequisites: pre1Id    469
# pre2Id    618
# pre3Id    622
# pre4Id    473
# pre5Id    591
# Name: 110, dtype: object
#
# Processing question 111 (Área de triángulos, paralelogramos, trapecios y figuras irregulares)...
# Retrieved prerequisite IDs: 589,616,618,530,532
# Padded ID list: ['589', '616', '618', '530', '532']
# Row 111 prerequisites: pre1Id    589
# pre2Id    616
# pre3Id    618
# pre4Id    530
# pre5Id    532
# Name: 111, dtype: object
#
# Processing question 112 (Operatoria de vectores)...
# Retrieved prerequisite IDs: 615,475,550,551,642
# Padded ID list: ['615', '475', '550', '551', '642']
# Row 112 prerequisites: pre1Id    615
# pre2Id    475
# pre3Id    550
# pre4Id    551
# pre5Id    642
# Name: 112, dtype: object
#
# Processing question 113 (Teorema de pitágoras)...
# Retrieved prerequisite IDs: 469,486,613,614,591
# Padded ID list: ['469', '486', '613', '614', '591']
# Row 113 prerequisites: pre1Id    469
# pre2Id    486
# pre3Id    613
# pre4Id    614
# pre5Id    591
# Name: 113, dtype: object
#
# Processing question 114 (Perímetro y Área del círculo)...
# Retrieved prerequisite IDs: 618,532,658,660,550
# Padded ID list: ['618', '532', '658', '660', '550']
# Row 114 prerequisites: pre1Id    618
# pre2Id    532
# pre3Id    658
# pre4Id    660
# pre5Id    550
# Name: 114, dtype: object
#
# Processing question 115 (Reflexión)...
# Retrieved prerequisite IDs: 615,474,550,618,621
# Padded ID list: ['615', '474', '550', '618', '621']
# Row 115 prerequisites: pre1Id    615
# pre2Id    474
# pre3Id    550
# pre4Id    618
# pre5Id    621
# Name: 115, dtype: object
#
# Processing question 116 (Vector Desplazamiento)...
# Retrieved prerequisite IDs: 618,473,615,622,478
# Padded ID list: ['618', '473', '615', '622', '478']
# Row 116 prerequisites: pre1Id    618
# pre2Id    473
# pre3Id    615
# pre4Id    622
# pre5Id    478
# Name: 116, dtype: object
#
# Processing question 117 (Homotecia de Forma Vectorial)...
# Retrieved prerequisite IDs: 475,615,532,590,540
# Padded ID list: ['475', '615', '532', '590', '540']
# Row 117 prerequisites: pre1Id    475
# pre2Id    615
# pre3Id    532
# pre4Id    590
# pre5Id    540
# Name: 117, dtype: object
#
# Processing question 118 (Teorema de Euclides)...
# Retrieved prerequisite IDs: 634,469,613,614,468
# Padded ID list: ['634', '469', '613', '614', '468']
# Row 118 prerequisites: pre1Id    634
# pre2Id    469
# pre3Id    613
# pre4Id    614
# pre5Id    468
# Name: 118, dtype: object
#
# Processing question 119 (Volumen del Cono)...
# Retrieved prerequisite IDs: 588,618,610,538,643
# Padded ID list: ['588', '618', '610', '538', '643']
# Row 119 prerequisites: pre1Id    588
# pre2Id    618
# pre3Id    610
# pre4Id    538
# pre5Id    643
# Name: 119, dtype: object
#
# Processing question 120 (Suma de ángulos interiores y exteriores de polígonos)...
# Retrieved prerequisite IDs: 621,644,622,467,618
# Padded ID list: ['621', '644', '622', '467', '618']
# Row 120 prerequisites: pre1Id    621
# pre2Id    644
# pre3Id    622
# pre4Id    467
# pre5Id    618
# Name: 120, dtype: object
#
# Processing question 121 (Área y Volumen de la Esfera)...
# Retrieved prerequisite IDs: 588,634,618,623,488
# Padded ID list: ['588', '634', '618', '623', '488']
# Row 121 prerequisites: pre1Id    588
# pre2Id    634
# pre3Id    618
# pre4Id    623
# pre5Id    488
# Name: 121, dtype: object
#
# Processing question 122 (Razones Trigonométricas)...
# Retrieved prerequisite IDs: 644,621,469,483,607
# Padded ID list: ['644', '621', '469', '483', '607']
# Row 122 prerequisites: pre1Id    644
# pre2Id    621
# pre3Id    469
# pre4Id    483
# pre5Id    607
# Name: 122, dtype: object
#
# Processing question 123 (Área de paralelogramos, triángulos y trapecios)...
# Retrieved prerequisite IDs: 618,616,550,600,473
# Padded ID list: ['618', '616', '550', '600', '473']
# Row 123 prerequisites: pre1Id    618
# pre2Id    616
# pre3Id    550
# pre4Id    600
# pre5Id    473
# Name: 123, dtype: object
#
# Processing question 124 (Área del Cono)...
# Retrieved prerequisite IDs: 588,618,634,603,621
# Padded ID list: ['588', '618', '634', '603', '621']
# Row 124 prerequisites: pre1Id    588
# pre2Id    618
# pre3Id    634
# pre4Id    603
# pre5Id    621
# Name: 124, dtype: object
#
# Processing question 125 (Ángulos complementarios y suplementarios)...
# Retrieved prerequisite IDs: 607,587,613,432,467
# Padded ID list: ['607', '587', '613', '432', '467']
# Row 125 prerequisites: pre1Id    607
# pre2Id    587
# pre3Id    613
# pre4Id    432
# pre5Id    467
# Name: 125, dtype: object
#
# Processing question 126 (Volumen del Cono)...
# Retrieved prerequisite IDs: 588,618,538,532,533
# Padded ID list: ['588', '618', '538', '532', '533']
# Row 126 prerequisites: pre1Id    588
# pre2Id    618
# pre3Id    538
# pre4Id    532
# pre5Id    533
# Name: 126, dtype: object
#
# Processing question 127 (Vector Desplazamiento)...
# Retrieved prerequisite IDs: 615,550,549,529,473
# Padded ID list: ['615', '550', '549', '529', '473']
# Row 127 prerequisites: pre1Id    615
# pre2Id    550
# pre3Id    549
# pre4Id    529
# pre5Id    473
# Name: 127, dtype: object
#
# Processing question 128 (Operatoria de vectores)...
# Retrieved prerequisite IDs: 615,479,492,490,617
# Padded ID list: ['615', '479', '492', '490', '617']
# Row 128 prerequisites: pre1Id    615
# pre2Id    479
# pre3Id    492
# pre4Id    490
# pre5Id    617
# Name: 128, dtype: object
#
# Processing question 129 (Volumen del Cono)...
# Retrieved prerequisite IDs: 469,618,588,591,603
# Padded ID list: ['469', '618', '588', '591', '603']
# Row 129 prerequisites: pre1Id    469
# pre2Id    618
# pre3Id    588
# pre4Id    591
# pre5Id    603
# Name: 129, dtype: object
#
# Processing question 130 (Operatoria de vectores)...
# Retrieved prerequisite IDs: 615,590,642,475,551
# Padded ID list: ['615', '590', '642', '475', '551']
# Row 130 prerequisites: pre1Id    615
# pre2Id    590
# pre3Id    642
# pre4Id    475
# pre5Id    551
# Name: 130, dtype: object
#
# Processing question 131 (Proyecciones de Vectores con Razones Trigonométricas)...
# Retrieved prerequisite IDs: 642,590,644,469,525
# Padded ID list: ['642', '590', '644', '469', '525']
# Row 131 prerequisites: pre1Id    642
# pre2Id    590
# pre3Id    644
# pre4Id    469
# pre5Id    525
# Name: 131, dtype: object
#
# Processing question 132 (Perímetro y Área de sectores y segmentos circulares)...
# Retrieved prerequisite IDs: 588,471,618,644,661
# Padded ID list: ['588', '471', '618', '644', '661']
# Row 132 prerequisites: pre1Id    588
# pre2Id    471
# pre3Id    618
# pre4Id    644
# pre5Id    661
# Name: 132, dtype: object
#
# Processing question 133 (Razones Trigonométricas)...
# Retrieved prerequisite IDs: 615,644,469,607,642
# Padded ID list: ['615', '644', '469', '607', '642']
# Row 133 prerequisites: pre1Id    615
# pre2Id    644
# pre3Id    469
# pre4Id    607
# pre5Id    642
# Name: 133, dtype: object
#
# Processing question 134 (Perímetro y Área de sectores y segmentos circulares)...
# Retrieved prerequisite IDs: 588,618,471,643,619
# Padded ID list: ['588', '618', '471', '643', '619']
# Row 134 prerequisites: pre1Id    588
# pre2Id    618
# pre3Id    471
# pre4Id    643
# pre5Id    619
# Name: 134, dtype: object
#
# Processing question 135 (Perímetro y Área del círculo)...
# Retrieved prerequisite IDs: 618,658,532,473,619
# Padded ID list: ['618', '658', '532', '473', '619']
# Row 135 prerequisites: pre1Id    618
# pre2Id    658
# pre3Id    532
# pre4Id    473
# pre5Id    619
# Name: 135, dtype: object
#
# Processing question 136 (Área de triángulos, paralelogramos, trapecios y figuras irregulares)...
# Retrieved prerequisite IDs: 589,600,601,618,660
# Padded ID list: ['589', '600', '601', '618', '660']
# Row 136 prerequisites: pre1Id    589
# pre2Id    600
# pre3Id    601
# pre4Id    618
# pre5Id    660
# Name: 136, dtype: object
#
# Processing question 137 (Teorema de Tales)...
# Error processing row 137: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
#
# Processing question 138 (Área de triángulos, paralelogramos, trapecios y figuras irregulares)...
# Retrieved prerequisite IDs: 618,532,533,530,660
# Padded ID list: ['618', '532', '533', '530', '660']
# Row 138 prerequisites: pre1Id    618
# pre2Id    532
# pre3Id    533
# pre4Id    530
# pre5Id    660
# Name: 138, dtype: object
#
# Processing question 139 (Teorema de Tales)...
# Retrieved prerequisite IDs: 607,629,483,616,432
# Padded ID list: ['607', '629', '483', '616', '432']
# Row 139 prerequisites: pre1Id    607
# pre2Id    629
# pre3Id    483
# pre4Id    616
# pre5Id    432
# Name: 139, dtype: object
#
# Processing question 140 (Teorema de Tales)...
# Retrieved prerequisite IDs: 622,607,629,483,432
# Padded ID list: ['622', '607', '629', '483', '432']
# Row 140 prerequisites: pre1Id    622
# pre2Id    607
# pre3Id    629
# pre4Id    483
# pre5Id    432
# Name: 140, dtype: object
#
# Processing question 141 (Teorema de Tales)...
# Retrieved prerequisite IDs: 621,616,618,589,607
# Padded ID list: ['621', '616', '618', '589', '607']
# Row 141 prerequisites: pre1Id    621
# pre2Id    616
# pre3Id    618
# pre4Id    589
# pre5Id    607
# Name: 141, dtype: object
#
# Processing question 142 (Magnitud de vectores)...
# Retrieved prerequisite IDs: 475,550,540,613,602
# Padded ID list: ['475', '550', '540', '613', '602']
# Row 142 prerequisites: pre1Id    475
# pre2Id    550
# pre3Id    540
# pre4Id    613
# pre5Id    602
# Name: 142, dtype: object
#
# Processing question 143 (Razones Trigonométricas)...
# Retrieved prerequisite IDs: 621,618,622,607,469
# Padded ID list: ['621', '618', '622', '607', '469']
# Row 143 prerequisites: pre1Id    621
# pre2Id    618
# pre3Id    622
# pre4Id    607
# pre5Id    469
# Name: 143, dtype: object
#
# Processing question 144 (Teorema de pitágoras)...
# Retrieved prerequisite IDs: 615,641,474,469,492
# Padded ID list: ['615', '641', '474', '469', '492']
# Row 144 prerequisites: pre1Id    615
# pre2Id    641
# pre3Id    474
# pre4Id    469
# pre5Id    492
# Name: 144, dtype: object
#
# Processing question 145 (Razones Trigonométricas)...
# Retrieved prerequisite IDs: 621,469,644,607,613
# Padded ID list: ['621', '469', '644', '607', '613']
# Row 145 prerequisites: pre1Id    621
# pre2Id    469
# pre3Id    644
# pre4Id    607
# pre5Id    613
# Name: 145, dtype: object
#
# Processing question 146 (Razones Trigonométricas)...
# Retrieved prerequisite IDs: 658,662,659,644,607
# Padded ID list: ['658', '662', '659', '644', '607']
# Row 146 prerequisites: pre1Id    658
# pre2Id    662
# pre3Id    659
# pre4Id    644
# pre5Id    607
# Name: 146, dtype: object
#
# Processing question 147 (Modelos a Escala)...
# Retrieved prerequisite IDs: 619,629,607,661,533
# Padded ID list: ['619', '629', '607', '661', '533']
# Row 147 prerequisites: pre1Id    619
# pre2Id    629
# pre3Id    607
# pre4Id    661
# pre5Id    533
# Name: 147, dtype: object
#
# Processing question 148 (Homotecia de Forma Vectorial)...
# Retrieved prerequisite IDs: 615,475,532,658,613
# Padded ID list: ['615', '475', '532', '658', '613']
# Row 148 prerequisites: pre1Id    615
# pre2Id    475
# pre3Id    532
# pre4Id    658
# pre5Id    613
# Name: 148, dtype: object
#
# Processing question 149 (Área de triángulos, paralelogramos, trapecios y figuras irregulares)...
# Retrieved prerequisite IDs: 658,532,533,618,530
# Padded ID list: ['658', '532', '533', '618', '530']
# Row 149 prerequisites: pre1Id    658
# pre2Id    532
# pre3Id    533
# pre4Id    618
# pre5Id    530
# Name: 149, dtype: object
#
# Processing question 150 (Tablas de frecuencia)...
# Retrieved prerequisite IDs: 628,663,626,625,596
# Padded ID list: ['628', '663', '626', '625', '596']
# Row 150 prerequisites: pre1Id    628
# pre2Id    663
# pre3Id    626
# pre4Id    625
# pre5Id    596
# Name: 150, dtype: object
#
# Processing question 151 (Tablas de frecuencia)...
# Retrieved prerequisite IDs: 625,663,530,533,661
# Padded ID list: ['625', '663', '530', '533', '661']
# Row 151 prerequisites: pre1Id    625
# pre2Id    663
# pre3Id    530
# pre4Id    533
# pre5Id    661
# Name: 151, dtype: object
#
# Processing question 152 (Suma y producto de probabilidades)...
# Retrieved prerequisite IDs: 634,618,626,596,512
# Padded ID list: ['634', '618', '626', '596', '512']
# Row 152 prerequisites: pre1Id    634
# pre2Id    618
# pre3Id    626
# pre4Id    596
# pre5Id    512
# Name: 152, dtype: object
#
# Processing question 153 (Medidas de Tendencia Central)...
# Retrieved prerequisite IDs: 664,663,497,494,660
# Padded ID list: ['664', '663', '497', '494', '660']
# Row 153 prerequisites: pre1Id    664
# pre2Id    663
# pre3Id    497
# pre4Id    494
# pre5Id    660
# Name: 153, dtype: object
#
# Processing question 154 (Diagrama de Cajón)...
# Retrieved prerequisite IDs: 537,660,663,662,498
# Padded ID list: ['537', '660', '663', '662', '498']
# Row 154 prerequisites: pre1Id    537
# pre2Id    660
# pre3Id    663
# pre4Id    662
# pre5Id    498
# Name: 154, dtype: object
#
# Processing question 155 (Probabilidad condicional)...
# Retrieved prerequisite IDs: 626,512,596,663,603
# Padded ID list: ['626', '512', '596', '663', '603']
# Row 155 prerequisites: pre1Id    626
# pre2Id    512
# pre3Id    596
# pre4Id    663
# pre5Id    603
# Name: 155, dtype: object
#
# Processing question 156 (Tablas de frecuencia)...
# Retrieved prerequisite IDs: 663,660,530,658,664
# Padded ID list: ['663', '660', '530', '658', '664']
# Row 156 prerequisites: pre1Id    663
# pre2Id    660
# pre3Id    530
# pre4Id    658
# pre5Id    664
# Name: 156, dtype: object
#
# Processing question 157 (Suma y producto de probabilidades)...
# Retrieved prerequisite IDs: 512,626,596,604,409
# Padded ID list: ['512', '626', '596', '604', '409']
# Row 157 prerequisites: pre1Id    512
# pre2Id    626
# pre3Id    596
# pre4Id    604
# pre5Id    409
# Name: 157, dtype: object
#
# Processing question 158 (Regla de LaPlace)...
# Retrieved prerequisite IDs: 626,596,604,550,663
# Padded ID list: ['626', '596', '604', '550', '663']
# Row 158 prerequisites: pre1Id    626
# pre2Id    596
# pre3Id    604
# pre4Id    550
# pre5Id    663
# Name: 158, dtype: object
#
# Processing question 159 (Comprensión e interpretación del promedio)...
# Retrieved prerequisite IDs: 658,530,533,603,544
# Padded ID list: ['658', '530', '533', '603', '544']
# Row 159 prerequisites: pre1Id    658
# pre2Id    530
# pre3Id    533
# pre4Id    603
# pre5Id    544
# Name: 159, dtype: object
#
# Processing question 160 (Regla de LaPlace)...
# Retrieved prerequisite IDs: 626,596,604,627,511
# Padded ID list: ['626', '596', '604', '627', '511']
# Row 160 prerequisites: pre1Id    626
# pre2Id    596
# pre3Id    604
# pre4Id    627
# pre5Id    511
# Name: 160, dtype: object
#
# Processing question 161 (Técnicas de conteo)...
# Retrieved prerequisite IDs: 626,631,602,596,630
# Padded ID list: ['626', '631', '602', '596', '630']
# Row 161 prerequisites: pre1Id    626
# pre2Id    631
# pre3Id    602
# pre4Id    596
# pre5Id    630
# Name: 161, dtype: object
#
# Processing question 162 (Suma y producto de probabilidades)...
# Retrieved prerequisite IDs: 589,634,512,604,416
# Padded ID list: ['589', '634', '512', '604', '416']
# Row 162 prerequisites: pre1Id    589
# pre2Id    634
# pre3Id    512
# pre4Id    604
# pre5Id    416
# Name: 162, dtype: object
#
# Processing question 163 (Tablas de frecuencia)...
# Retrieved prerequisite IDs: 537,416,533,660,663
# Padded ID list: ['537', '416', '533', '660', '663']
# Row 163 prerequisites: pre1Id    537
# pre2Id    416
# pre3Id    533
# pre4Id    660
# pre5Id    663
# Name: 163, dtype: object
#
# Processing question 164 (Diagrama de Cajón)...
# Retrieved prerequisite IDs: 537,416,662,498,663
# Padded ID list: ['537', '416', '662', '498', '663']
# Row 164 prerequisites: pre1Id    537
# pre2Id    416
# pre3Id    662
# pre4Id    498
# pre5Id    663
# Name: 164, dtype: object
#
# Processing question 165 (Diagrama de Cajón)...
# Retrieved prerequisite IDs: 663,664,625,595,497
# Padded ID list: ['663', '664', '625', '595', '497']
# Row 165 prerequisites: pre1Id    663
# pre2Id    664
# pre3Id    625
# pre4Id    595
# pre5Id    497
# Name: 165, dtype: object
#
# Processing question 166 (Suma y producto de probabilidades)...
# Retrieved prerequisite IDs: 512,596,626,643,631
# Padded ID list: ['512', '596', '626', '643', '631']
# Row 166 prerequisites: pre1Id    512
# pre2Id    596
# pre3Id    626
# pre4Id    643
# pre5Id    631
# Name: 166, dtype: object
#
# Processing question 167 (Tablas de frecuencia)...
# Retrieved prerequisite IDs: 537,663,530,416,626
# Padded ID list: ['537', '663', '530', '416', '626']
# Row 167 prerequisites: pre1Id    537
# pre2Id    663
# pre3Id    530
# pre4Id    416
# pre5Id    626
# Name: 167, dtype: object
#
# Processing question 168 (Técnicas de conteo)...
# Retrieved prerequisite IDs: 530,532,533,626,631
# Padded ID list: ['530', '532', '533', '626', '631']
# Row 168 prerequisites: pre1Id    530
# pre2Id    532
# pre3Id    533
# pre4Id    626
# pre5Id    631
# Name: 168, dtype: object
#
# Processing question 169 (Tablas de frecuencia)...
# Retrieved prerequisite IDs: 663,596,607,626,543
# Padded ID list: ['663', '596', '607', '626', '543']
# Row 169 prerequisites: pre1Id    663
# pre2Id    596
# pre3Id    607
# pre4Id    626
# pre5Id    543
# Name: 169, dtype: object
#
# Processing question 170 (Información en Tablas de Frecuencia)...
# Retrieved prerequisite IDs: 530,664,628,630,508
# Padded ID list: ['530', '664', '628', '630', '508']
# Row 170 prerequisites: pre1Id    530
# pre2Id    664
# pre3Id    628
# pre4Id    630
# pre5Id    508
# Name: 170, dtype: object
#
# Processing question 171 (Medidas de posición)...
# Retrieved prerequisite IDs: 663,508,537,625,497
# Padded ID list: ['663', '508', '537', '625', '497']
# Row 171 prerequisites: pre1Id    663
# pre2Id    508
# pre3Id    537
# pre4Id    625
# pre5Id    497
# Name: 171, dtype: object
#
# Processing question 172 (Medidas de posición)...
# Retrieved prerequisite IDs: 660,663,625,530,595
# Padded ID list: ['660', '663', '625', '530', '595']
# Row 172 prerequisites: pre1Id    660
# pre2Id    663
# pre3Id    625
# pre4Id    530
# pre5Id    595
# Name: 172, dtype: object
#
# Processing question 173 (Regla de LaPlace)...
# Retrieved prerequisite IDs: 626,596,532,613,535
# Padded ID list: ['626', '596', '532', '613', '535']
# Row 173 prerequisites: pre1Id    626
# pre2Id    596
# pre3Id    532
# pre4Id    613
# pre5Id    535
# Name: 173, dtype: object
#
# Processing question 174 (Tablas de frecuencia)...
# Retrieved prerequisite IDs: 663,664,628,658,662
# Padded ID list: ['663', '664', '628', '658', '662']
# Row 174 prerequisites: pre1Id    663
# pre2Id    664
# pre3Id    628
# pre4Id    658
# pre5Id    662
# Name: 174, dtype: object
#
# Processing question 175 (Medidas de tendencia central con datos agrupados)...
# Retrieved prerequisite IDs: 625,497,494,660,595
# Padded ID list: ['625', '497', '494', '660', '595']
# Row 175 prerequisites: pre1Id    625
# pre2Id    497
# pre3Id    494
# pre4Id    660
# pre5Id    595
# Name: 175, dtype: object
#
# Processing question 176 (Tablas de frecuencia)...
# Retrieved prerequisite IDs: 537,416,607,658,602
# Padded ID list: ['537', '416', '607', '658', '602']
# Row 176 prerequisites: pre1Id    537
# pre2Id    416
# pre3Id    607
# pre4Id    658
# pre5Id    602
# Name: 176, dtype: object
#
# Processing question 177 (Tablas de frecuencia)...
# Retrieved prerequisite IDs: 537,533,530,607,416
# Padded ID list: ['537', '533', '530', '607', '416']
# Row 177 prerequisites: pre1Id    537
# pre2Id    533
# pre3Id    530
# pre4Id    607
# pre5Id    416
# Name: 177, dtype: object
#
# Processing question 178 (Técnicas de conteo)...
# Retrieved prerequisite IDs: 626,532,603,613,530
# Padded ID list: ['626', '532', '603', '613', '530']
# Row 178 prerequisites: pre1Id    626
# pre2Id    532
# pre3Id    603
# pre4Id    613
# pre5Id    530
# Name: 178, dtype: object
#
# Processing question 179 (Técnicas de conteo)...
# Retrieved prerequisite IDs: 631,626,532,533,602
# Padded ID list: ['631', '626', '532', '533', '602']
# Row 179 prerequisites: pre1Id    631
# pre2Id    626
# pre3Id    532
# pre4Id    533
# pre5Id    602
# Name: 179, dtype: object
#
# Processing question 180 (Medidas de Tendencia Central)...
# Retrieved prerequisite IDs: 663,530,533,625,508
# Padded ID list: ['663', '530', '533', '625', '508']
# Row 180 prerequisites: pre1Id    663
# pre2Id    530
# pre3Id    533
# pre4Id    625
# pre5Id    508
# Name: 180, dtype: object
#
# Processing question 181 (Rango de un conjunto de datos)...
# Retrieved prerequisite IDs: 664,630,663,660,550
# Padded ID list: ['664', '630', '663', '660', '550']
# Row 181 prerequisites: pre1Id    664
# pre2Id    630
# pre3Id    663
# pre4Id    660
# pre5Id    550
# Name: 181, dtype: object
#
# Processing question 182 (Comprensión e interpretación del promedio)...
# Retrieved prerequisite IDs: 658,662,550,601,603
# Padded ID list: ['658', '662', '550', '601', '603']
# Row 182 prerequisites: pre1Id    658
# pre2Id    662
# pre3Id    550
# pre4Id    601
# pre5Id    603
# Name: 182, dtype: object
#
# Processing question 183 (Técnicas de conteo)...
# Retrieved prerequisite IDs: 600,603,532,626,535
# Padded ID list: ['600', '603', '532', '626', '535']
# Row 183 prerequisites: pre1Id    600
# pre2Id    603
# pre3Id    532
# pre4Id    626
# pre5Id    535
# Name: 183, dtype: object
#
# Processing question 184 (Tablas de frecuencia)...
# Retrieved prerequisite IDs: 537,416,626,596,508
# Padded ID list: ['537', '416', '626', '596', '508']
# Row 184 prerequisites: pre1Id    537
# pre2Id    416
# pre3Id    626
# pre4Id    596
# pre5Id    508
# Name: 184, dtype: object
#
# Processing question 185 (Medidas de tendencia central con datos no agrupados)...
# Retrieved prerequisite IDs: 664,630,663,625,508
# Padded ID list: ['664', '630', '663', '625', '508']
# Row 185 prerequisites: pre1Id    664
# pre2Id    630
# pre3Id    663
# pre4Id    625
# pre5Id    508
# Name: 185, dtype: object
#
# Processing question 186 (Comprensión e interpretación del promedio)...
# Retrieved prerequisite IDs: 530,533,658,603,663
# Padded ID list: ['530', '533', '658', '603', '663']
# Row 186 prerequisites: pre1Id    530
# pre2Id    533
# pre3Id    658
# pre4Id    603
# pre5Id    663
# Name: 186, dtype: object
#
# Processing question 187 (Rango de un conjunto de datos)...
# Retrieved prerequisite IDs: 658,660,530,531,550
# Padded ID list: ['658', '660', '530', '531', '550']
# Row 187 prerequisites: pre1Id    658
# pre2Id    660
# pre3Id    530
# pre4Id    531
# pre5Id    550
# Name: 187, dtype: object
#
# Processing question 188 (Suma y producto de probabilidades)...
# Retrieved prerequisite IDs: 512,589,618,596,473
# Padded ID list: ['512', '589', '618', '596', '473']
# Row 188 prerequisites: pre1Id    512
# pre2Id    589
# pre3Id    618
# pre4Id    596
# pre5Id    473
# Name: 188, dtype: object
#
# Processing question 189 (Tablas de frecuencia)...
# Retrieved prerequisite IDs: 663,664,530,537,416
# Padded ID list: ['663', '664', '530', '537', '416']
# Row 189 prerequisites: pre1Id    663
# pre2Id    664
# pre3Id    530
# pre4Id    537
# pre5Id    416
# Name: 189, dtype: object
#
# Processing question 190 (Tablas de frecuencia)...
# Retrieved prerequisite IDs: 663,512,626,412,530
# Padded ID list: ['663', '512', '626', '412', '530']
# Row 190 prerequisites: pre1Id    663
# pre2Id    512
# pre3Id    626
# pre4Id    412
# pre5Id    530
# Name: 190, dtype: object
#
# Processing question 191 (Histogramas)...
# Retrieved prerequisite IDs: 630,664,508,595,625
# Padded ID list: ['630', '664', '508', '595', '625']
# Row 191 prerequisites: pre1Id    630
# pre2Id    664
# pre3Id    508
# pre4Id    595
# pre5Id    625
# Name: 191, dtype: object
#
# Processing question 192 (Suma y producto de probabilidades)...
# Retrieved prerequisite IDs: 589,634,512,596,626
# Padded ID list: ['589', '634', '512', '596', '626']
# Row 192 prerequisites: pre1Id    589
# pre2Id    634
# pre3Id    512
# pre4Id    596
# pre5Id    626
# Name: 192, dtype: object
#
# Processing question 193 (Probabilidad condicional)...
# Retrieved prerequisite IDs: 512,626,596,604,542
# Padded ID list: ['512', '626', '596', '604', '542']
# Row 193 prerequisites: pre1Id    512
# pre2Id    626
# pre3Id    596
# pre4Id    604
# pre5Id    542
# Name: 193, dtype: object
#
# Processing question 194 (Técnicas de conteo)...
# Retrieved prerequisite IDs: 661,532,626,603,613
# Padded ID list: ['661', '532', '626', '603', '613']
# Row 194 prerequisites: pre1Id    661
# pre2Id    532
# pre3Id    626
# pre4Id    603
# pre5Id    613
# Name: 194, dtype: object
#
# Processing question 195 (Tablas de frecuencia)...
# Retrieved prerequisite IDs: 537,416,607,533,530
# Padded ID list: ['537', '416', '607', '533', '530']
# Row 195 prerequisites: pre1Id    537
# pre2Id    416
# pre3Id    607
# pre4Id    533
# pre5Id    530
# Name: 195, dtype: object
#
# Processing question 196 (Suma y producto de probabilidades)...
# Retrieved prerequisite IDs: 589,512,596,607,409
# Padded ID list: ['589', '512', '596', '607', '409']
# Row 196 prerequisites: pre1Id    589
# pre2Id    512
# pre3Id    596
# pre4Id    607
# pre5Id    409
# Name: 196, dtype: object
#
# Processing question 197 (Técnicas de conteo)...
# Retrieved prerequisite IDs: 658,550,600,631,626
# Padded ID list: ['658', '550', '600', '631', '626']
# Row 197 prerequisites: pre1Id    658
# pre2Id    550
# pre3Id    600
# pre4Id    631
# pre5Id    626
# Name: 197, dtype: object
#
# Processing question 198 (Medidas de tendencia central con datos agrupados)...
# Retrieved prerequisite IDs: 663,595,494,664,660
# Padded ID list: ['663', '595', '494', '664', '660']
# Row 198 prerequisites: pre1Id    663
# pre2Id    595
# pre3Id    494
# pre4Id    664
# pre5Id    660
# Name: 198, dtype: object
#
# Processing question 199 (Probabilidad condicional)...
# Retrieved prerequisite IDs: 626,596,512,604,537
# Padded ID list: ['626', '596', '512', '604', '537']
# Row 199 prerequisites: pre1Id    626
# pre2Id    596
# pre3Id    512
# pre4Id    604
# pre5Id    537
# Name: 199, dtype: object
#
# Finished processing all questions
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 31
#      28 print("\nFinished processing all questions")
#      30 # Convert the new columns to int
# ---> 31 selected_questions_df[['pre1Id', 'pre2Id', 'pre3Id', 'pre4Id', 'pre5Id']] = selected_questions_df[['pre1Id', 'pre2Id', 'pre3Id', 'pre4Id', 'pre5Id']].astype(int)
#      33 # Save the dataframe with prerequisites to CSV
#      34 selected_questions_df.to_csv('../data/new/selected_questions_with_prereqs_200.csv', index=False)
#
# File ~/miniconda3/envs/full/lib/python3.11/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/miniconda3/envs/full/lib/python3.11/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/miniconda3/envs/full/lib/python3.11/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/miniconda3/envs/full/lib/python3.11/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/miniconda3/envs/full/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/miniconda3/envs/full/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/miniconda3/envs/full/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'

# %%
# First convert None values to NaN
selected_questions_df[['pre1Id', 'pre2Id', 'pre3Id', 'pre4Id', 'pre5Id']] = selected_questions_df[['pre1Id', 'pre2Id', 'pre3Id', 'pre4Id', 'pre5Id']].fillna(-1)

# Then convert to int
selected_questions_df[['pre1Id', 'pre2Id', 'pre3Id', 'pre4Id', 'pre5Id']] = selected_questions_df[['pre1Id', 'pre2Id', 'pre3Id', 'pre4Id', 'pre5Id']].astype(int)

# Save the dataframe with prerequisites to CSV
selected_questions_df.to_csv('../data/new/selected_questions_with_prereqs_200.csv', index=False)
print("Saved dataframe with prerequisites to data/new/selected_questions_with_prereqs_200.csv")
# Out:
# Saved dataframe with prerequisites to data/new/selected_questions_with_prereqs_200.csv

# %%
# Import topics data
topics_df = pd.read_csv('../data/new/topics_full.csv')
print(f"Loaded {len(topics_df)} topics from topics_full.csv")

# Add prerequisite topic names
for i in range(1,6):
    # Join with topics_df to get names for each prerequisite ID
    selected_questions_df[f'pre{i}TopicName'] = selected_questions_df[f'pre{i}Id'].map(
        topics_df.set_index('topicId')['topicName']
    )
    selected_questions_df[f'pre{i}SubjectName'] = selected_questions_df[f'pre{i}Id'].map(
        topics_df.set_index('topicId')['subjectName']
    )
    selected_questions_df[f'pre{i}AxisName'] = selected_questions_df[f'pre{i}Id'].map(
        topics_df.set_index('topicId')['axisName']
    )

selected_questions_df.head()
# Out:
# Loaded 246 topics from topics_full.csv
#    answerId  isCorrect                                      questionTitle  \
# 0   1347929      False  En un estacionamiento hay `1.200` vehículos, d...
# 1   1452301      False  ¿Cuál es el valor de la expresión `1/5-2/3`?<b...
# 2   1593181      False     `487 - (-462 ÷ 11) + (1 · 31) + (125 - 96) = `
# 3   1462188      False  <div>La siguiente tabla, muestra la proyección...
# 4   1491793      False  <div>Juan estaba apostando en el casino con ci...
#
#         correctOptionLetter        studentAnswerLetter  studentAge  userLevel  \
# 0                    `300`                       `250`        13.0   0.166604
# 1                   `-7/15`                    `-1/15`        16.0  -0.152740
# 2                     `589`                      `590`         NaN  -3.000000
# 3                  IV=1,006                   IV=2,006         NaN  -1.014222
# 4  `9` dólares australianos  `19` dólares australianos        13.0  -2.263959
#
#    userLevelPercentile                                       topicName  \
# 0                 66.0                                    Porcentajes
# 1                 58.0              Suma y resta de números racionales
# 2                  0.0         Operatoria combinada de números enteros
# 3                 39.0  Cambio Porcentual Constante, Interés Compuesto
# 4                 14.0               División por números de una cifra
#
#           subjectName  ... pre2AxisName  \
# 0         Porcentajes  ...      Números
# 1  Números racionales  ...      Números
# 2     Números Enteros  ...      Números
# 3  Números racionales  ...      Números
# 4   Números Naturales  ...      Números
#
#                                     pre3TopicName     pre3SubjectName  \
# 0             Multiplicación de números naturales   Números Naturales
# 1        Adición y sustracción de números enteros     Números Enteros
# 2                     División de números enteros     Números Enteros
# 3  Multiplicación y división de números decimales  Números racionales
# 4             Multiplicación de números naturales   Números Naturales
#
#   pre3AxisName                              pre4TopicName     pre4SubjectName  \
# 0      Números           Problemas con cuatro operaciones   Números Naturales
# 1      Números        Multiplicación de números naturales   Números Naturales
# 2      Números  Operatoria combinada de números naturales   Números Naturales
# 3      Números       Transformación de fracción a decimal  Números racionales
# 4      Números              División de números naturales   Números Naturales
#
#    pre4AxisName                                      pre5TopicName  \
# 0       Números                          Suma de números naturales
# 1       Números                   Comparación de números naturales
# 2       Números  Ubicación y orden de números enteros en la rec...
# 3       Números                          Aproximación por redondeo
# 4       Números                                   Valor Posicional
#
#      pre5SubjectName  pre5AxisName
# 0  Números Naturales       Números
# 1  Números Naturales       Números
# 2    Números Enteros       Números
# 3  Números Naturales       Números
# 4  Números Naturales       Números
#
# [5 rows x 36 columns]

# %%
# Load master data
master_df = pd.read_csv('../data/new/master_final.csv')
print(f"Loaded {len(master_df)} rows from master_final.csv")

# Add user_id column by matching answer_id with master_df
selected_questions_df['userId'] = selected_questions_df['answerId'].map(
    master_df.set_index('answer_id')['user_id']
)
print(f"Added user_id column to selected_questions_df")
# Out:
# Loaded 196083 rows from master_final.csv
# Added user_id column to selected_questions_df

# %%
# Create columns for prerequisite levels
for i in range(1,6):
    # Initialize empty column
    selected_questions_df[f'pre{i}Level'] = None
    
    # For each row in selected_questions_df
    for idx, row in selected_questions_df.iterrows():
        # Get relevant answers from master_df:
        # - Same user_id as current question
        # - Same topic_id as prerequisite i
        # - answer_id less than current question's answer_id
        relevant_answers = master_df[
            (master_df['user_id'] == row['userId']) & 
            (master_df['topic_id'] == row[f'pre{i}Id']) &
            (master_df['answer_id'] < row['answerId'])
        ]
        
        # If there are relevant answers, get the level from the most recent one
        if len(relevant_answers) > 0:
            most_recent = relevant_answers.nlargest(1, 'answer_id')
            selected_questions_df.at[idx, f'pre{i}Level'] = most_recent['user_level'].iloc[0]

print("Added prerequisite level columns")

# Save the dataframe to CSV
output_path = '../data/new/questions_with_prerequisites.csv'
selected_questions_df.to_csv(output_path, index=False)
print(f"Saved dataframe to {output_path}")
# Out:
# Added prerequisite level columns
# Saved dataframe to ../data/new/questions_with_prerequisites.csv

# %% [markdown]
# I want to create 5 new columns in selected_questions_df: pre1Level, pre2Level, pre3Level, pre4Level, pre5Level. Those levels are stored in the user_level column of the master_df. To get the level of each prerequisite, you have to find the rows that have the same userId (user_id) and topic_id, and get the user_level.
# But here is the catch: you have to order the answers in master_df by answer_id and then get the one with largest answer_id but that is lower than the answer_id of the question. (that way we get the most recent one, but without looking into the future)
